# %%
pip install haystack-ai accelerate "sentence-transformers>=3.0.0" "datasets>=2.6.1"
# Out:
# Requirement already satisfied: haystack-ai in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: sentence-transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: datasets>=2.6.1 in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: haystack-experimental in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (0.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (3.1.4)
# Requirement already satisfied: lazy-imports in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (0.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (10.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (1.54.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (2.2.2)
# Requirement already satisfied: posthog in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (3.7.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0 in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (9.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (4.12.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=3.0.0) (4.46.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=3.0.0) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=3.0.0) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=3.0.0) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.6.1) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.6.1) (3.11.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (1.17.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.6.1) (4.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->haystack-ai) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->haystack-ai) (2024.8.30)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=3.0.0) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=3.0.0) (0.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->haystack-ai) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->haystack-ai) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->haystack-ai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog->haystack-ai) (2.2.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=3.0.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=3.0.0) (3.5.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->haystack-ai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.1.0->haystack-ai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->haystack-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->haystack-ai) (2.23.4)

# %% [markdown]
# Knowing you’re using this tutorial helps us decide where to invest our efforts to build a better product but you can always opt out by commenting the following line. See [Telemetry](https://docs.haystack.deepset.ai/docs/enabling-telemetry) for more details.

# %% [markdown]
# ## Load data into the `DocumentStore`

# %% [markdown]
# Before you can use this data in the extractive pipeline, you'll use an indexing pipeline to fetch it, process it, and load it into the document store.
#
#
# The data has already been cleaned and preprocessed, so turning it into Haystack `Documents` is fairly straightfoward.
#
# Using an `InMemoryDocumentStore` here keeps things simple. However, this general approach would work with [any document store that Haystack 2.0 supports](https://docs.haystack.deepset.ai/docs/document-store).
#
# The `SentenceTransformersDocumentEmbedder` transforms each `Document` into a vector. Here we've used [`sentence-transformers/multi-qa-mpnet-base-dot-v1`](https://huggingface.co/sentence-transformers/multi-qa-mpnet-base-dot-v1). You can substitute any embedding model you like, as long as you use the same one in your extractive pipeline.
#
# Lastly, the `DocumentWriter` writes the vectorized documents to the `DocumentStore`.

# %%
import pandas as pd

# %%
#from datasets import load_dataset
from haystack import Document
from haystack import Pipeline
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.readers import ExtractiveReader
from haystack.components.embedders import SentenceTransformersDocumentEmbedder
from haystack.components.writers import DocumentWriter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/df_for_LLM_v2.csv'

# %%
df_for_LLM = pd.read_csv(file_path)

# %%
df_for_LLM
# Out:
#                               name  \
# 0                       San Carlos
# 1                    Angel's salon
# 2             La Casa del Plastico
# 3                     EPA Solarium
# 4                    Policia Upala
# ..                             ...
# 143                Coopeguanacaste
# 144  Liberia International Airport
# 145                 Playa del Coco
# 146                     Mega Super
# 147                      Zi Lounge
#
#                                     property_tag_old_2  \
# 0                                       Hardware Store
# 1                                           Beauty Bar
# 2                                     Department Store
# 3                     Department Store, Hardware Store
# 4              Police Department, Information Services
# ..                                                 ...
# 143                                          Utilities
# 144                                            Airport
# 145                                            Beaches
# 146                                        Supermarket
# 147  Restaurant, Bar, International, Seafood, Pizza...
#
#                             property_email  \
# 0              mmora@depositosancarlos.com
# 1                   myrnaangel@hotmail.com
# 2               info@lacasadelplastico.com
# 3                      contacto@xr.epa.biz
# 4                 no information available
# ..                                     ...
# 143  servicioalcliente@coopeguanacaste.com
# 144           \ninfo@guanacasteairport.com
# 145               no information available
# 146               no information available
# 147                      info@zilounge.com
#
#                            property_hours_of_operation property_location  \
# 0    Monday - Friday 7:00 AM- 5:00 PM, Saturday 7:0...    Playa del Coco
# 1    Monday 9:00 AM - 6:00 PM, Tuesday - Saturday 9...    Playa del Coco
# 2    Monday - Saturday 8:00 AM - 6:00 PM, Sunday  C...    Playa del Coco
# 3    Monday - Friday 9:00 AM - 5:00 PM, Saturday 9:...           Liberia
# 4    Monday - Friday 8:00 AM - 4:00 PM, Saturday - ...          Canalete
# ..                                                 ...               ...
# 143  Monday - Saturday 7:00 AM - 5:00 PM,\nSunday  ...    Playa del Coco
# 144                 Monday - Sunday 6:00 AM - 12:00 AM           Liberia
# 145                           no information available    Playa del Coco
# 146  Monday - Saturday 7:00 AM - 10:00 PM Sunday 7:...    Playa del Coco
# 147                 Monday - Sunday 11:00 AM - 2:30 AM    Playa del Coco
#
#                                   property_description  \
# 0    Deposito San Carlos is a largest building mate...
# 1    Angel's Salon is a professional hair and beaut...
# 2    La Casa del Plastico specializes in the sale o...
# 3    EPA Solarium - Hardware and Home Goods Store o...
# 4    Policia Upala - Police Department and Informat...
# ..                                                 ...
# 143  Coopeguanacaste R.L. is a cooperative in Guana...
# 144  Daniel Oduber Quirós International Airport (LI...
# 145  Playas del Coco is a vibrant hub of activity, ...
# 146  Mega Super offers a wide range of products, fr...
# 147  In this bar-restaurant, there are dishes and d...
#
#         property_phone_number  \
# 0              +506 2670-1211
# 1    no information available
# 2              +506 2670-0700
# 3    no information available
# 4              +506 2470-0235
# ..                        ...
# 143            +506 2681-4700
# 144            +506 2666-9600
# 145  no information available
# 146            +506 2670-1239
# 147            +506 8888-3939
#
#                                          combined_text
# 0    San Carlos, Hardware Store, mmora@depositosanc...
# 1    Angel's salon, Beauty Bar, myrnaangel@hotmail....
# 2    La Casa del Plastico, Department Store, info@l...
# 3    EPA Solarium, Department Store, Hardware Store...
# 4    Policia Upala, Police Department, Information ...
# ..                                                 ...
# 143  Coopeguanacaste, Utilities, servicioalcliente@...
# 144  Liberia International Airport, Airport, \ninfo...
# 145  Playa del Coco, Beaches, no information availa...
# 146  Mega Super, Supermarket, no information availa...
# 147  Zi Lounge, Restaurant, Bar, International, Sea...
#
# [148 rows x 8 columns]

# %%
# # Пример №1, в контенте только описание заведений
# documents = [
#     Document(
#         content=f"{row['property_description']}",
#         meta={
#             "name": row['name'],
#             "tags": row['property_tag_old_2'],
#             "email": row['property_email'],
#             "location": row['property_location'],
#             "phone_number": row['property_phone_number'],
#             "hours_of_operation": row['property_hours_of_operation']
#         }
#     )
#     for _, row in df_for_LLM.iterrows()
# ]

# %%
# # Пример №2, в контенте также режим работы
# documents = [
#     Document(
#         content=f"{row['property_description']}\nHours: {row['property_hours_of_operation']}",
#         meta={
#             "name": row['name'],
#             "tags": row['property_tag_old_2'],
#             "email": row['property_email'],
#             "location": row['property_location'],
#             "phone_number": row['property_phone_number']
#         }
#     )
#     for _, row in df_for_LLM.iterrows()
# ]

# %%
# Пример №3, в контенте combined_text то есть содержимое всех столбцов
documents = [
    Document(
        content=f"{row['combined_text']}",

    )
    for _, row in df_for_LLM.iterrows()
]

# %%
# # Пример №4, в контенте combined_text, а также есть meta
# documents = [
#     Document(
#         content=f"{row['combined_text']}",
#         meta={
#             "name": row['name'],
#             "tags": row['property_tag_old_2'],
#             "email": row['property_email'],
#             "location": row['property_location'],
#             "phone_number": row['property_phone_number'],
#             "hours_of_operation": row['property_hours_of_operation']
#         }
#     )
#     for _, row in df_for_LLM.iterrows()
# ]

# %%
documents
# Out:
# [Document(id=15d5fa5cb856487f11d2bf5c60d218b65b97056a8485c246e7313d05bd7afe8e, content: 'San Carlos, Hardware Store, mmora@depositosancarlos.com, Monday - Friday 7:00 AM- 5:00 PM, Saturday ...'),
#  Document(id=f2a36e72ab889a4a0d9fc4d9e4f513226cbba05cf774689c596ae541f9488c11, content: 'Angel's salon, Beauty Bar, myrnaangel@hotmail.com, Monday 9:00 AM - 6:00 PM, Tuesday - Saturday 9:00...'),
#  Document(id=df5708ebb664a1d8728a25452a763a5736931ac8776a5eaba13d68e2c434b604, content: 'La Casa del Plastico, Department Store, info@lacasadelplastico.com, Monday - Saturday 8:00 AM - 6:00...'),
#  Document(id=652bb2e573623ca2933923f5322e29e26601f617f0ceb673e0374bc1adaaa266, content: 'EPA Solarium, Department Store, Hardware Store, contacto@xr.epa.biz, Monday - Friday 9:00 AM - 5:00 ...'),
#  Document(id=f28c9df328974b5c719ed0b76c1146c1a33913d0470d3ce70dc6e08960592fc4, content: 'Policia Upala, Police Department, Information Services, no information available, Monday - Friday 8:...'),
#  Document(id=5f0e74a34b5ad712ca1a6c8e752bd253a3b8ff0da3596ac42314e9266f2938fa, content: 'Drive, Car Repair, Motorcycle Repair, Electric Vehicle Repair, drivecococr@gmail.com, Monday - Frida...'),
#  Document(id=3063ca79f1938c951b30cd66c3dca254ac07221d6845e9187cbe1da6b674a9df, content: 'Dual, Post Office, Delivery, servicioalcliente@dualservicioscr.com, Monday - Friday 9:00 AM - 6:00 P...'),
#  Document(id=638421a41548dc8d5b44130b3729e833a1fc796b0393bd6cd55b1a20bf5f7ef1, content: 'Full market, Supermarket, no information available, Monday - Sunday Everyday 24/7, Liberia, Full Mar...'),
#  Document(id=9dcd0373d439d96d5e54fb3ed2872c5a670569edb1b0359f90192ae46d176966, content: 'Maxi Pali, Supermarket, sac@wal-mart.com, Monday -  Friday 8:00 AM - 8:00 PM,
#  Saturday 9:00 AM - 8:0...'),
#  Document(id=a10cedc4d5a27f46fe62a925d096d2fe8db5eee6d696212a0154298025346d6e, content: 'Fraiche, Perfume Store, Speciality & Gift Shops, info@fraiche.co.cr, Monday  - Sunday 9:00 AM - 6:00...'),
#  Document(id=281746e46c4f81f25471142ffef5d63ec2e7807f3b4ec8c91b99e5a77787a04e, content: 'Jiron, Bed Shop, liberia@jiron.com, Monday - Saturday 9:00 AM - 7:00 PM, Sunday  9:00 AM - 5:00 PM, ...'),
#  Document(id=d104b791ff66d3301f437720920dbcf740ebc645132e27e24aec235b36044767, content: 'Ekono, Department Store, info@ekonocr.com, Monday - Saturday  8:30 AM - 8:00 PM, Sunday  9:00 AM - 5...'),
#  Document(id=2bc4dd24ad939dd57ff8d1526024657479bcfacbcbf613388114957227831c11, content: 'Baruch, Barbershop, no information available, Monday - Sunday  7:30 AM- 8:00 PM, Playa Ocotal, Baruc...'),
#  Document(id=58cc5f2461c12168123d4ede7ec216b73ab0a840ce6d5f82bb4b4eaf763a7204, content: 'Costa Doc, Medical Services, info@costadoc.com, Monday - Sunday Open 24 hours, Playa del Coco, Costa...'),
#  Document(id=ae1862e70c8b2df7f297efe326266edbe9f42f36059c306d47fd353d2abbee52, content: 'Guiselle Rivera, Speciality & Gift Shops, guiselleriveracr@gmail.com, Monday - Saturday 10:00 AM - 7...'),
#  Document(id=db9510d422755825adc9f551974e1c45793e50a3797612eaffba8f7d73e4f2b6, content: 'Los Mangos 2, Supermarket, no information available, Monday - Sunday 8:00 AM - 9:00 PM, Playa Ocotal...'),
#  Document(id=8040a7468ca5e201f079fe41a25d46635ae6720df6fee901c6f5f2b9755c05b3, content: 'Gas station Full, Gas Station, Gasoline, katarsis.obl@gmail.com, Monday - Sunday Open 24 hours, no i...'),
#  Document(id=7b0954e87199ff69e2913b7d23f9d626632695dc10cf0d67758b83febe446ec3, content: 'M&M (Rambutan Restaurante), Restaurant, International, Coffee, Desserts, Meat, cesarilama@yahoo.es, ...'),
#  Document(id=64f55fac0a83837f87efdd7b96d78de23efc74e2da1528d82c3385cdc9075951, content: 'Banco BCT, Bank, ATM, info@corporacionbct.com
#  atencionalclientebct@corporacionbct.com, Monday - Frid...'),
#  Document(id=e68377c5673663e49f1f97ef6ba619cdf98649067495b99f4960da66f694f56e, content: 'El Lagar Do It Center, Hardware Store,  lagarenlinea@ellagar.com, Monday - Friday 7:00 AM - 6:00 PM,...'),
#  Document(id=d33491490d390b86299adcabaa7995f40460b282ecc8e213d365cd4fd9296b9c, content: 'Rent a Carrito, Golf Cart Rental, Golf Cart Repair, sales@rentacarrito.com, Monday - Friday 08:00 AM...'),
#  Document(id=4e3841490205b7cc6be5d5ba691592fb1f646648fa699dea350c1bfb3e47c239, content: 'Coco Market, Supermarket, no information available, Monday - Sunday 7:30 AM - 9:30 PM, Playa del Coc...'),
#  Document(id=0902d16a5956b99668b66405edddd3ba30af615eb3f9760a6597706cc52a1852, content: 'Eco Moda, Speciality & Gift Shops, no information available, Monday - Saturday 09:00 AM – 7:00 PM, S...'),
#  Document(id=0253b6ec60d574f0a0d8645f1a5fe8108bfae81b0d7b1da3147d25b258bb3fd7, content: 'Charging station Coopeguanacaste, EV Charging Station, no information available, Monday- Sunday Open...'),
#  Document(id=61633ef49f2c6cf9380f9b5e0f00f093a747c3666397a63e4742bf3034fd98d2, content: 'Taller Electroman, Car Repair, chimicc1975@gmail.com, Monday – Friday 8:00 AM – 5:00 PM, Saturday 8:...'),
#  Document(id=78c78475b551bde28bf1aa7f470df296eb2d2dda5d71588e7ee1ea8e3f118fe7, content: 'Mayca, Supermarket, lbadonarvaez@mayca.com, Monday – Saturday 8:00 AM – 7:00 PM, Sunday 9:00 AM – 5:...'),
#  Document(id=1f76f4da1cf4b229b91bb1b25a36b02e37a2404565fc911d2816347d54e5e1b2, content: 'Cinema Hermosa, Movie Theatres, no information available, Monday - Tuesday closed,  Wednesday - Sund...'),
#  Document(id=a343deca4937df9d6ee1c2305e312bf83811eafe69c24c8bf6ba8d1c7f42f2a4, content: 'Cleveland, Second Hand, no information available, Monday - Saturday 9:00 AM - 8:00 PM, Sunday  9:00 ...'),
#  Document(id=4c6765ed05356c9034c4ddd779e58fad9ebc652fda3cc915abd0253183e40dfb, content: 'Plaza Cocomar Gastro Market, Restaurant, Latin, Local, Kids Menu, Seafood, Casado, Ceviche, Meat, So...'),
#  Document(id=504935b2c221b94a24c16d37835661e2822858298dce71b53b0b3c9f5ee4601a, content: 'Pasamaneria Adriana, Speciality & Gift Shops, pasamadriana1@gmail.com, Monday - Saturday 9:00 AM - 6...'),
#  Document(id=f488b132115ae28a229c029ee51dac2fd113b4aa00c8103f09658fc7d1de2ed5, content: 'Nikkei, Restaurant, Fusion, Asian, Vegan, Sushi, Seafood, Meat, Soups, sales@pacifico-costarica.com,...'),
#  Document(id=05168f0308352c916f884f2a2696407ed5f66ba1079da0ab096824c5e81f562f, content: 'Panamar Seafood, Seafood Market, Fish Market, no information available, Monday - Sunday 09:00 AM - 0...'),
#  Document(id=60f848b2e6e544f327cf3abcceeeac96692ef9836c86b8958e0fb9f8837e0a5d, content: 'ArSof Barbershop, Barbershop, arsofbarbershop@gmail.com, Monday - Saturday 10:00 AM - 06:00 PM, Sund...'),
#  Document(id=610a267f91bca10ed2b79deed8c6ef402550ec60f425168418445d9ba7a123c5, content: 'Ginger, Restaurant, International, Fusion, Sushi, Pizza, Seafood, Salads Cocktails, Wine, GingerCost...'),
#  Document(id=d452f4b3a9c4b0e71ec4b96fdcac2a3829d8914f9db68a5833ee112797e7e0b5, content: 'Roberto's Restaurant -  La Gaviota Tropical, Restaurant, International, Vegetarian, Gluten-free, Sea...'),
#  Document(id=4183be01faeb471e8f415cb0340fbd0336069f26e0e445b24b2033db6a8637f0, content: 'La Gacela, Speciality & Gift Shops, no information available, Monday - Sunday 07:00 AM- 09:30 PM, Pl...'),
#  Document(id=4234a25ca4d38cf75f383b184948c6161467322a7404d815ac38a093989b84f3, content: 'Libre Verdad, Lawyer Services, info@libreverdad.com, Monday - Thursday 8:00 AM - 6:00 PM,  Friday 8:...'),
#  Document(id=273cda60e375fbd431a2e29ab4a75d58df67e2942283c453793d28054e166149, content: 'Claudio y Gloria, Restaurant, International, Seafood, Meat, Wine, Cocktails, Info@dondeclaudioyglori...'),
#  Document(id=d9aa59e0c3d4cc4b9dca2dbaa44fcbf664ca93adde59dd8e6e78fb8e5d55805a, content: 'Island Golf Cart Rentals, Golf Cart Rental, brikrogers@outlook.com, Monday - Sunday open 24 hours, P...'),
#  Document(id=51cb45003cc36666d5282256ea061597b91b8436b24d8ed3c31bc406dad961d0, content: 'Euro Taller Multiservicios Hermosa, Car Repair, no information available, Monday - Friday 7:45 AM - ...'),
#  Document(id=56b476adb7bd642f930e840d6d476e8f0ff2cd1d637dc478461b360a798a6037, content: 'Servicentro, Gas Station, Gasoline, no information available, Monday - Sunday 5:00 AM - 10:00 PM, Pl...'),
#  Document(id=ae22f644b11b85dc0484c56cf5519bd0d221489f4190c4fa389d8eb0b1203c59, content: 'Fish Spa, Spa, no information available, Monday - Sunday 10:00 AM - 7:00 PM, Playa del Coco, Fish Sp...'),
#  Document(id=a1f28c167acc286197b53afbc9712b64e7b67f030ed52901778ed38ba51c6dbe, content: 'Charging station BAC, EV Charging Station, no information available, Monday - Sunday Open 24 hours, ...'),
#  Document(id=8b81474f0e6afc29e9e8a561b5408bc8032bdb274738538542cb52443b3c5599, content: 'Ricky Tour's (, Horseback Riding Tours, Nature & Wildlife Tours, no information available, Monday-Su...'),
#  Document(id=277816b47b673effc5481b8559f528013d2d167a0d1ba3b56c761740a20f3e88, content: 'Frespan, Bakery, Pastry, no information available, Monday- Sunday 5:00 AM - 8:00 PM, Sardinal, Panad...'),
#  Document(id=e4c8d80512f9e911eb3879885088a741bb585d6f9280bb98091a180501927147, content: 'Panaderías Valle, Bakery, Pastry, Pizza, no information available, Monday - Sunday 6:00 AM  - 9:00 P...'),
#  Document(id=7bf82a2fc4bfbefcc1b56563f9c02b4f9f78145a2bf954985b7a6bd53c071609, content: 'PLT Pharmacy, Pharmacy, no information available, Monday - Saturday 08:00 AM - 07:00 PM, Sunday 08:0...'),
#  Document(id=7c647313cff59caf7ae209d931ff0dabdcdfd6b872925661ca127e9a4b26a085, content: 'Joyeria Quesada, Speciality & Gift Shops, no information available, Monday - Saturday  8:30 AM - 8:0...'),
#  Document(id=c7958c32f81e93bb22089a7371ea3f8d11b4c0b39a5b06892003ce8720d08024, content: 'Mouse Lamp, Appliance Store, info@mouselamp.com, Monday - Friday 09:00 AM - 06:00 PM, Saturday 09:00...'),
#  Document(id=5e03abd8bfb32989c0868f415010605a3d3762e481bea57e3019d782d6c90073, content: 'Bazar y Libreria Miluska, Speciality & Gift Shops, Stationery, no information available, Monday - Fr...'),
#  Document(id=22928e22ad05c54d00e57e217fbb83513ab34d274e4b4fdc92b027541337ac47, content: 'Coco China To Go, Restaurant, Chinese, Vegetarian, Pasta, Seafood, Soups, no information available, ...'),
#  Document(id=85309389d0a565f5075cafa6b293fbeea70fb140d5f54c80943ea776109cbfac, content: 'Tienda Nova, Speciality & Gift Shops, angielafuengli@icloud.com, Monday-Saturday 9:00 AM - 8:00 PM, ...'),
#  Document(id=d67febb682cc15300f047ad2d4fd8085ec436f56639cd52751b2ee981f265191, content: 'Mi Buen Trigo, Bakery, Pastry, Coffee, no information available, Monday - Sunday 5:00 AM - 7:00 PM, ...'),
#  Document(id=591afa2bc9d177a978946eb8da1cd93a1d72105dc68f93927b9354e394f61826, content: 'Ambar 82, Speciality & Gift Shops, ambarjrv82@gmail.com, Monday - Saturday 10:00 AM - 7:00 AM, Sunda...'),
#  Document(id=6ae77eef9ef3d81c808a5279828f34b22e97493737406f1cb9ebc6404bc40f65, content: 'Farmacia Guanacasteca, Pharmacy, no information available, Monday - Saturday 8:00 AM - 8:00 PM, Sund...'),
#  Document(id=740deb7f224d19610749ecdd1f7c2b944d4e22731572fec0fd0c6464497c78d2, content: 'BAC , Bank, ATM, no information available, Monday - Friday 9:00 AM - 5:00 PM Saturday 9:00 AM - 1:00...'),
#  Document(id=1e5e56a7d634b3fa44f36f5ec6a059c39e07d3bfb97566b20a9def99f48d80d9, content: 'Coco Rentals, Golf Cart Rental, Golf Cart Repair, golfcarts1@outlook.com, Monday - Friday 8:00 AM - ...'),
#  Document(id=6ccdafe6c54e9cf06440cef551701dc09ba7325e35f3f4b81116579c7b43b362, content: 'Me Time, Beauty Bar, no information available, Monday - Saturday  9:00 AM - 5:00 PM, Sunday - Closed...'),
#  Document(id=d9b5d10231738e9f0c6e44115b7169b80c4805fe6b262b5fc803685cba471925, content: 'Art Flower, Flower Shop, Speciality & Gift Shops, no information available, Monday - Saturday 8:00 A...'),
#  Document(id=c5b9e905aa5c2c6c08ed7f3b7f014b3f0aa587ac9e17adf21cddef549174ea1d, content: 'Intelec, Appliance Store, no information available, Monday - Saturday 9:00 AM - 7:00 PM, Sunday - Cl...'),
#  Document(id=ae546e36bdb333bf6f22949d43492b606dd72407b02382c7287bd38a1ae756f7, content: 'Sal y Fuego, Steakhouse, Kids Menu, Barbecue, Grill, Steak, Meat, Fast Food, Burgers, salyfuegocr202...'),
#  Document(id=df49489d53014567edb4c8783090b0b540c6b930021d06c44e3b6d34166ecbf2, content: 'Barberia Jehová Jireh, Barbershop, no information available, Monday - Sunday 8:00 AM- 6:00 PM, Sardi...'),
#  Document(id=24d5770e72fca604b87e05205c84fa5fa343a33956d5d5b7dba13e1fff22ce51, content: 'Hacienda El Viejo , Hiking Tours, Food Tours, Nature & Wildlife Tours, no information available, Mon...'),
#  Document(id=8a01ff5987715ab245f2567d25399223ef64c558ca9ea7108a96da7706966e43, content: 'Alma Santa, Restaurant, Latin, Vegetarian, Seafood, Barbecue, Soups, Pasta, reservations@pacifico-co...'),
#  Document(id=0259c633d15088de015f32391e35593c62914f2ccdb89c3a878ba00cdd7887aa, content: 'Aqua Sport, Restaurant, Bar, Latin, Vegetarian, Cocktails, Pizza, Seafood, Fast Food, infoaquarestau...'),
#  Document(id=7e0ba6c0c47b473dd9adb44178b58c7af7950cd415cb29eb56cbb34e37850751, content: 'Baccomer, Restaurant, Bar, Seafood, Pizza, no information available, Monday - Closed, Tuesday - Sund...'),
#  Document(id=8e96c20723b9a1c102d2c9cb0de3f3179a260876309629475721c435caf2af99, content: 'Cava, Restaurant, Bar, Meat, Wine, Beer, Alcohol, cavabarcostarica@gmail.com, Monday 3:00 PM – 10:00...'),
#  Document(id=770987ff26251a267b01ff01cf072279295516ec767295c8fe552066fdd2eacc, content: 'Anatot, Gas Station, Gasoline, no information available, Monday - Sunday Open 24 hours, Comunidad, A...'),
#  Document(id=718494340ccbaa9bc884ae1660d5b94a91e44c6110b53e4cecb8238ef93efec6, content: 'Discount Italian Store, Supermarket, Speciality Food Shop, freshfinefood1@gmail.com, Monday - Friday...'),
#  Document(id=4124fc4769a182f5acf7535ee9f8aa5e76bfa553d9b507c81f1f954643125bc9, content: 'Nouba PET, Veterinary Clinic, noubapet@gmail.com, Monday - Friday 8:30 AM - 4:30 PM, Saturday 09:00 ...'),
#  Document(id=a1a729a80cf6b6dbacc716117d56930487fdf5d7cd3af34c48246d7a7eb8dc86, content: 'Cafe Corazon, Cafe, Latin, American, Vegetarian, Vegan, Cocktails, Coffee, Salads, Desserts, cafecor...'),
#  Document(id=bb3b35280dc5cc27eeef405ae74c782bbdd0a0effbccdfa1fe74a9acb9f57e3c, content: 'Artelec, Appliance Store, tiendavirtual@artelec.cr, Monday - Friday 9:00 AM- 6:30 PM, Saturday 9:00 ...'),
#  Document(id=4e9608d62145f997de0688cf36e1e984333af72444b36f889bb34af26dbaad73, content: 'Mundo Màgico / Mundo Cosmetico, Speciality & Gift Shop, no information available, Monday  - Saturday...'),
#  Document(id=27d6798b4fe9bab691fe75b06eff3713bacb762dc03595882f0321e78fed63f8, content: 'Coco Beach Tattoo, Tattoo Studio, no information available, Monday - Saturday 11:00 AM - 8 PM, Sunda...'),
#  Document(id=cf977ae8a617bea49b34b6dd376830d8196171cc8c5a07100fee244413e9b025, content: 'Mr. Outlet, Outlet Stores, Speciality & Gift Shops, mroutletcostarica@gmail.com, Monday - Wednesday ...'),
#  Document(id=798fed74dce2afdf62d4ac43e0c501cf340fec292bda628e58b580a01900798e, content: 'Cafe de Playa, Restaurant, International, Seafood, Meat, Grill, Wine,  info.cafedeplaya@gmail.com,  ...'),
#  Document(id=e6cc39d4a7d4bfc759e051686d3bc1bffaafac4af3c6a988b9d325c96b97bd9c, content: 'Deep Blue Diving, Diving, dive@deepblue-diving.com, Monday - Sunday 07:00 AM- 04:00 PM, Playa del Co...'),
#  Document(id=637184d4f97a641e5450841a26086bdb9b51f5b3e9b3f063758848a598854252, content: 'Tandoor, Restaurant, Indian, Vegetarian, Soups, Meat,  info@tandoor-grill.com, Monday - Sunday 11:30...'),
#  Document(id=039d4994c201f4abb686b2aae8a9423a7e51e3f9f5c3de233582e756ab4a42f1, content: 'The Palms, Restaurant, Asian, Local, Kids Menu, Seafood, Pasta, Sushi, Ceviche, Gallo Pinto, Cocktai...'),
#  Document(id=3a5b16838c97ddbb6a5c1430a97c589692aaf765b6b40f3f98a1eb1912697b71, content: 'Java Coffee , Cafe, Coffee, Desserts, Salads, cafejavacr@gmail.com, Monday - Sunday 7:00 AM - 5:30 P...'),
#  Document(id=267989c9df3f885f52a3c12736a16ab34a2dcde12e30f51aba876be0a68d623c, content: 'Le Coq, Restaurant, Mediterranean, Gluten-free, Vegan, Salads, Meat, Coffee, holalecoq@gmail.com, Mo...'),
#  Document(id=e0705ddaeedd9539c512af5c62f8a51bff1e129e6362535805cff3d6db3b94cb, content: 'Tortuga Bar, Bar, Fast Food, Seafood, Meat, Pasta, Pizza, Cocktails, pioneros@pionerosdelcoco.com   ...'),
#  Document(id=782b234474f941691d1b6ba9b055e27aecb0f98c37d328cc9afa3a230ad62cad, content: 'Jardin Tropical, Soda, Local, Latin, Kids Menu, Chifrijo, Ceviche, Seafood, Fast Food, Salads, Burge...'),
#  Document(id=9376f7c497ef946ae6486880c22895d5186dc61fe92368131a29c1292f848cde, content: 'Bar El Ancla, Restaurant, Bar, Spanish, Seafood, Pasta, Salads, Meat, Cocktails, Alcohol, no informa...'),
#  Document(id=cc139782dc4d122ac91693b6b22d33b249f734db13d4a99adb5cdbf811da4636, content: 'Teresita, Soda, Local, Latin, Casado, Ceviche, Meat, Seafood, Salads, no information available, Mond...'),
#  Document(id=e94822773c77d904bd7694e7c4620f3174c9f3906c8af72639100d1066b5d458, content: 'Thermomania, Parks, no information available, Monday - Sunday 8:00 AM - 10:00 PM, Bagaces, Thermo Ma...'),
#  Document(id=b1230f57fd0185432950630b1f2f3ae6fb74b391cb180db7e500c2fa2d5a9393, content: 'Volcán Rincón de la Vieja, Hiking, Watefalls, Volcanos, no information available, Tuesday - Sunday 7...'),
#  Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...'),
#  Document(id=b1920ebda99eefd048e0677e1957ff63c5c5bbab550f26ea07fece43a7dd7449, content: 'Yummy Café, Cafe, American, Desserts, Coffee, Fast Food, Burgers, no information available, Monday -...'),
#  Document(id=ba7572ea9cb4a917aad0eafaabb5be8d66559c09c58e1532a1d8c1a3d7b5c222, content: 'Verde Salvia, Restaurant, Italian, Mediterranean, Vegetarian, Vegan, Gluten-free, Seafood, Pizza, Me...'),
#  Document(id=ebf761a4dd51cbd042492fcb3d1fd31c395b7b886f506969edfc08dc58b9fd52, content: 'Subway, Fast Food, no information available, Monday -  Sunday 7:00 AM - 10:00 PM, Playa del Coco, Su...'),
#  Document(id=1fc422fd27c7db093e71e22f5b49fde8b31e30870db047e93a708f242f1aa2cb, content: 'Simbiosis Bistro, Cafe, International, Coffee, Desserts, no information available, Monday – Friday 7...'),
#  Document(id=01c29f05aef6803216a5d6d8de6bef63e358e31ce4108c4e08dfb8ba50d46df5, content: 'Santorini, Restaurant, Greek, Mediterranean, Gluten-free, Kids Menu, Seafood, Meat, Alcohol, Salads,...'),
#  Document(id=a048a67642a9bab3e0a13fb98044cf3020975d3413cd66eaf3c1e0b0f96229b2, content: 'Pops, Cafe, Coffee, Desserts, no information available, Monday - Sunday 10:00 AM - 09:00 PM, Playa d...'),
#  Document(id=3bc43e9af5442854f0bd6b630c6742db97e5c2e8c89b4edd1e878223e3920a0b, content: 'El Jardín, Canteen, International, Pastry, Coffee, Desserts, no information available, Monday - Sund...'),
#  Document(id=77d1b533143ee4d8a809f21026f581f8996371be37c1f7e12ca707ac24f3c45d, content: 'Numu, Restaurant, International, Kids Menu, Seafood, Meat, Salads, Cocktails, Beer, Wine, no informa...'),
#  Document(id=09b7135706b4c717d27b81c647c751c2948d0f63a2543ce770f48460355e2772, content: 'Naans and Curries, Restaurant, Indian, Kids Menu, Vegetarian, Vegan, Gluten-free, Soups, Salads, Mea...'),
#  Document(id=fb97df4c5f847ffaa190979e530fd01dd745aa361584121c22ac498de4b0bffb, content: 'Guayoyo, Cafe, Vegan, Vegetarian, Coffee, Pastry, no information available, Monday - Friday 07:00 AM...'),
#  Document(id=ffb8a233480bd1565845a30458829300cf66d604a6c44cd40e547ffe5c9429b3, content: 'Get Tanked, Bar, Restaurant, Latin, International, Soups, Meat, Pasta, Cocktails, Beer, no informati...'),
#  Document(id=7a66b2593c9f6a04d893d9a926e5fc0039b061cdae4d6b247226597633c15c78, content: 'Coconutz, Restaurant, Bar, Latin, American, Mexican, Salads, Fast Food, Pizza, Meat, Grill, Burgers,...'),
#  Document(id=99da5abfa522861d19d9e301cb399cf761dc508e6ead635e5c1ea2072c44b094, content: 'Coco Pizza Company, Pizzeria, Pet-friendly, Pizza, no information available, Monday-Sunday 4:00 PM -...'),
#  Document(id=405f7cd86ac5e07d32563fc1a405a880e63683425d28ec683b30d3d712f29129, content: 'The Sausage Guy, Speciality Food Shop, Meat, no information available, Monday - Sunday 08:00 AM - 07...'),
#  Document(id=93936769d01c5d62c8b95785302cecb6d8bfc7399fc674393faf16eddc94e8fb, content: 'The GYM, Fitness, Sport, thegymcocobeach@gmail.com, Monday - Friday 6:00 AM - 9:00 PM, Saturday 6:00...'),
#  Document(id=ca9ab75ac0792cf4f280ca47a3aa0670910f392accab62c19fad3a5bda5469d6, content: 'Grupo Económico, Supermarket, no information available, Monday - Sunday 8:00 AM - 9:00 PM, Playa del...'),
#  Document(id=17664ad7772384b18e5a80bfa86253bbd9fff09c283283466e92dd228115097b, content: 'Opticas , Optical Store, servicioalcliente@vision.co.cr, Monday - Saturday 9:00 AM - 7:00 PM, Sunday...'),
#  Document(id=27e430a2a0ecd0da8ad6bd3ab51274fc797e2a53e7b38c1d66d8dd3315680a4e, content: 'La Casona, Restaurant, Local, Gallo Pinto, Casado, Chifrijo, Soups, Meat, Coffee, no information ava...'),
#  Document(id=7ce1cd4922fd80f28483cb71f17a368ce4cbb5df3caa9bef5a84ce2945b3c8c4, content: 'Coco Gym Fitness, Fitness, Sport, entrenadorfisico@gmail.com, Monday - Friday 06:00 AM- 08:00 PM (Lu...'),
#  Document(id=d9b213e4b2a0c741b36380cd5b801d6264f541c287aa511f048d132b2311170b, content: 'Coco Blue, Cleaning, no information available, Monday - Friday 08:00 AM - 05:00 PM Lunch time: 12:00...'),
#  Document(id=c3b0bd10fa4227d39b5f849eab4716f316423f1af07cf7fd3881e59062a39803, content: 'Farmacia Maxi Pali , Pharmacy, no information available, Monday - Sunday 9:00 AM - 9:00 PM, Playa de...'),
#  Document(id=c67bd420271bd4ddb3d925bbc3dde2d9dc17fa21bd5bccdeb1758ca647afc3de, content: 'Hot Wok, Restaurant, Asian, Vegan, Vegetarian, Sushi, Soups, Pasta, Meat, no information available, ...'),
#  Document(id=e22355468dbac36acecc49852f9bf8c9b40207d3b3d2e3df054a51ce593bbd55, content: 'Ferreteria La Chorrera, Hardware Store, ferrechorrera@gmail.com, Monday - Saturday 7:00 AM - 5:30 PM...'),
#  Document(id=b7f220af5c86527fd4443269ce16431808e539f3923446a325e9a51526dc111a, content: 'ADICOCO, Community Center, infoadicoco@gmail.com, no information available, Playa del Coco, ADICOCO ...'),
#  Document(id=f52e3cb5e2b1dcb19e91833040958cf4f3fb07edef53c914ece976c79226f0cf, content: 'El Jobo, Fishing Store, cotecpes1467@outlook.com, Monday - Friday 7:30 AM - 5:30 PM, Saturday 7:30 A...'),
#  Document(id=70457a485c96260330e02359dfc0c22986b77c948dec1519e16ec99803979e5b, content: 'Playa Calson de Pobre, Beaches, no information available, no information available, Playa Calson de ...'),
#  Document(id=6342201df19b911553662e9e481f0f9bf914e8ccfe1a9a939ea63639ab259042, content: 'Playa Penca, Beaches, no information available, no information available, Playa Penca, Playa Penca i...'),
#  Document(id=30b233b5228c1a769d297da91da10285a1921362d126ef7c8217c6a3a2ffd336, content: 'Playa Tamarindo, Beaches, no information available, no information available, Playa Tamarindo, Tamar...'),
#  Document(id=10382ad43f0027b40918c907e03ecf26b1f75534cbea6e47be9bdb4b243a6a43, content: 'Playa Gringo, Beaches, no information available, no information available, Playa Gringo, Playa Gring...'),
#  Document(id=37b85b312227673e2a9b0b3fde9d84f8270f497de5bec0f8850c896ad1a2bb3a, content: 'Playa Panama, Beaches, no information available, no information available, Playa Panama, Playa Panam...'),
#  Document(id=ac66a1c02849fab40742c4604ef651406c94c3d8427cd0b4e0e7930738cde4f1, content: 'Playa Pez Vela, Beaches, no information available, no information available, Playa Pez Vela, Playa P...'),
#  Document(id=ce605dad4f840feeb7c1b30517b8ae07a9997ddc8b12cb2700ca3614a2c2a046, content: 'Playa Hermosa, Beaches, no information available, no information available, Playa Hermosa, Playa Her...'),
#  Document(id=5f5ca79ba3996b2bc434ad2a010142c09a4917d60e5f868e1d11bccaa063d432, content: 'Playa Ocotal, Beaches, no information available, no information available, Playa Ocotal, This beach ...'),
#  Document(id=c2ad5fd870f1f6ec3b9d32625c1b922ca699f766b841a2958231ea4bae018668, content: 'Monge, Appliance Store, atencionalcliente@grupomonge.com, Monday - Saturday 09:00 AM - 06:00 PM, Sun...'),
#  Document(id=176ad9ae0da75e823e7c96f4f6ec9cfd2e7c1c8aca0970fa94dcd55e1b3ea839, content: 'Correos de Costa Rica, Post Office,  srvcliente@correos.go.cr, Monday - Friday 8:00 AM - 5:30 PM, Sa...'),
#  Document(id=759aab4f18e1c4dfdcb24d73e9b83d679280d6d37e862a2843f03f33e632ecf5, content: 'AyA, Utilities, no information available,
#  Monday - Friday 7:00 AM - 3:00 PM, Saturday - Sunday  Clo...'),
#  Document(id=2061ceaed4e6779f6287a4947af6a982c0346f7b83a3c8bc0bfc0ddddccf0873, content: 'MExpress, Appliance Store, admelcoco@mexpresscr.com, Monday - Sunday 9:00 AM - 7:00 PM, Playa del Co...'),
#  Document(id=d02bafcf57ddce8d35296d2b9b4c54a19add55f744de6dcf57d65555d61a8946, content: 'Gollo, Appliance Store, no information available, Monday - Saturday 9:00 AM - 6:00 PM, Sunday - Clos...'),
#  Document(id=f212e29ede28260ec740926d68ec9f55c690d621572cea4b4125ef1e1e8bf65b, content: 'Luperon, Supermarket, luperon@superluperon.com, Monday - Sunday 7:30 AM - 9:00 PM, Playa del Coco, S...'),
#  Document(id=f43e643623817940024cde5e6fa9e5196cb53440b9c79134d740cc6f85ada0b0, content: 'GD Computadoras - Plaza Luperon, Appliance Store, info@gdcomputadoras.com, Monday-Saturday 9:30 AM -...'),
#  Document(id=848b3095fec9e11917b15f938eef628b451a25f9574bc27c41436edcab2de24a, content: 'Mega Super - Plaza Luperon, Supermarket, no information available, Monday - Saturday 7:00 AM - 10:00...'),
#  Document(id=48769409320ba29e036497cfff9b620c4f202e31dc1d51daf24cbd45502a678a, content: 'Auto Mercado, Supermarket, no information available, Monday - Saturday 8:00 AM- 9:00 PM, Sunday 8:00...'),
#  Document(id=5e9aca8fe6af0aa9da59980cc2e98f1898bc2be46b9cca39079e061adaa6e894, content: 'Maxi Pali, Supermarket, no information available, Monday - Sunday 07:30 AM- 09:00 PM, Playa del Coco...'),
#  Document(id=a4b90b07bfd423479bdc3c6d44b7f37f2948b2c3eeeac81a8790ee0a78447238, content: 'Liberty Liberia, Telecommunications, no information available, Monday - Saturday  - 8:00 AM - 5:00 P...'),
#  Document(id=ab4762fe32b9836c91f6e4c92a0f3a369752d3c7d888f713e677245069f749c1, content: 'The Palms (mini market), Convenience Store, no information available, Monday - Sunday 7:00 AM - 10:0...'),
#  Document(id=25093bdbe2ec03b5be212765f50b0d43c62b4187111b8022811b0772a185c9b1, content: 'Agro Los Cartagos, Grocery Store, no information available, Monday-Saturday 8:00 AM- 7:30 PM,  Sunda...'),
#  Document(id=36819e1b847c1e047e92e5481714b5a1a1edfc166bc395ef6327f6e2f7036043, content: 'New China, Supermarket, no information available, Monday - Sunday 8:00 AM - 9:00 PM, Playa del Coco,...'),
#  Document(id=bcc26ed6bd5be69e39602e935dbba8817eee97a3bb18a916d5e9ebc3d64ba760, content: 'Super New China, Supermarket, 271404678@qq.com, Monday - Sunday 8:00 AM - 9:00 PM, Playa del Coco, S...'),
#  Document(id=61821ff19d3e366b61885bcb7260bf5bcf3f93e2433060e6983614d8a152e51a, content: 'Super Compro, Supermarket, servicioalcliente@supercompro.crservicioalcliente@gessacr.com
#
#  , Monday -...'),
#  Document(id=6c4804bb3397cc659708355fe5ac3c9bc4f293c0c5e967f17db5b5e036668403, content: 'Farmacia Azul, Pharmacy, farmaciaazulcr@gmail.com, Monday - Friday 7:00 AM - 6:00 PM, Saturday 7:00 ...'),
#  Document(id=608cfd08e388127ade4bbb0d28a717e59a3e173cd52fda8d7282f1b616b08dd0, content: 'Salazar, Fish Market, no information available, Monday - Sunday 7:00 AM - 6:00 PM, Playa del Coco, S...'),
#  Document(id=da0562b3fc2e4c08550b88eaa2183e5c01685de0310fdc31c313e055a8b8506d, content: 'Fischel, Pharmacy , info@fischel.co.cr, Monday - Thursday 08:00 AM - 8:00 PM, Friday -  Saturday 9:0...'),
#  Document(id=15de7a4b9aef42476fdea3a1e7be39340d67d9adb561e92af5838aa5af43e414, content: 'ATM BAC, Bank, ATM, no information available, Monday - Sunday Open 24 hours, Playa del Coco, ATM BAC...'),
#  Document(id=1da70591c2307b5dca9a8378b8ba5217987500c78d0ebbe929756c896f203e6b, content: 'Banco de Costa Rica, Bank, ATM, no information available, Monday - Friday 9:00 AM - 3:30 PM, Saturda...'),
#  Document(id=6db43054577d45fda796ba29d25cf838d5abece367c888e5937c5cb1157264cd, content: 'Banco Nacional, Bank, ATM, no information available, Monday - Friday 8:30 AM - 3:30 PM, Saturday - S...'),
#  Document(id=45d8e40039413ae9d6fa6964d98cf2d30781c9977aa86f10babce9ec2a2aecc9, content: 'Coopeguanacaste, Utilities, servicioalcliente@coopeguanacaste.com, Monday - Saturday 7:00 AM - 5:00 ...'),
#  Document(id=b5a3b50f50dd73deca1df2e3b64d5a01a22d7fac4f125eeaee0a1f6df43cde9a, content: 'Liberia International Airport, Airport,
#  info@guanacasteairport.com, Monday - Sunday 6:00 AM - 12:00...'),
#  Document(id=58580deb002857e157db9e0e7462fec6ea3078288190e1f34e527661d3688a8a, content: 'Playa del Coco, Beaches, no information available, no information available, Playa del Coco, Playas ...'),
#  Document(id=2b59e1d0199f9c0a650fc533ae67c64e1ed9fdc063ffaf86acc0870abbd36a8b, content: 'Mega Super, Supermarket, no information available, Monday - Saturday 7:00 AM - 10:00 PM Sunday 7:00 ...'),
#  Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...')]

# %%
model = "sentence-transformers/multi-qa-mpnet-base-dot-v1"

#model = "deepset/roberta-base-squad2"

#model="google/tapas-base-finetuned-wtq"                             #Хочу проверить модель, которая сделана для задач table QA. Также для использования в docs возьму:
                                                                     #Пример №1, где в контенте только описание заведений. Не подходит, так как на вход нужен только pd dataframe


#model="microsoft/tapex-base"                                         #Видимо они все так устроены, также на вход нужен pd dataframe


#model="deepset/roberta-large-squad2"

#model="deepset/deberta-v3-large-squad2"

#model="deepset/deberta-v3-base-squad2"

#model="deepset/bert-base-cased-squad2"                                #Учитывает регистр

#Далее буду пробовать модели из библиотеки sentence-transformers.

#model = "sentence-transformers/multi-qa-distilbert-dot-v1"

#model = "sentence-transformers/multi-qa-MiniLM-L6-dot-v1"

#model = "sentence-transformers/msmarco-bert-base-dot-v5"

#model = "sentence-transformers/msmarco-distilbert-base-tas-b"

#model = "sentence-transformers/msmarco-MiniLM-L12-cos-v5"

document_store = InMemoryDocumentStore()

indexing_pipeline = Pipeline()

indexing_pipeline.add_component(instance=SentenceTransformersDocumentEmbedder(model=model), name="embedder")
indexing_pipeline.add_component(instance=DocumentWriter(document_store=document_store), name="writer")
indexing_pipeline.connect("embedder.documents", "writer.documents")

indexing_pipeline.run({"documents": documents})
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# {'writer': {'documents_written': 148}}

# %% [markdown]
# ## Build an Extractive QA Pipeline
#
# Your extractive QA pipeline will consist of three components: an embedder, retriever, and reader.
#
# - The `SentenceTransformersTextEmbedder` turns a query into a vector, usaing the same embedding model defined above.
#
# - Vector search allows the retriever to efficiently return relevant documents from the document store. Retrievers are tightly coupled with document stores; thus, you'll use an `InMemoryEmbeddingRetriever`to go with the `InMemoryDocumentStore`.
#
# - The `ExtractiveReader` returns answers to that query, as well as their location in the source document, and a confidence score.

# %%
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.readers import ExtractiveReader
from haystack.components.embedders import SentenceTransformersTextEmbedder

# %%
retriever = InMemoryEmbeddingRetriever(document_store=document_store)
reader = ExtractiveReader()
reader.warm_up()

extractive_qa_pipeline = Pipeline()

extractive_qa_pipeline.add_component(instance=SentenceTransformersTextEmbedder(model=model), name="embedder")
extractive_qa_pipeline.add_component(instance=retriever, name="retriever")
extractive_qa_pipeline.add_component(instance=reader, name="reader")

extractive_qa_pipeline.connect("embedder.embedding", "retriever.query_embedding")
extractive_qa_pipeline.connect("retriever.documents", "reader.documents")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7b9e20b5cc40>
# 🚅 Components
#   - embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
#   - reader: ExtractiveReader
# 🛤️ Connections
#   - embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> reader.documents (List[Document])

# %%
query = "What are the opening hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8432546854019165, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 0.6435337060392761), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8176264762878418, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 0.6435337060392761), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.790582001209259, data='11:30 AM-10:00 PM', document=Document(id=637184d4f97a641e5450841a26086bdb9b51f5b3e9b3f063758848a598854252, content: 'Tandoor, Restaurant, Indian, Vegetarian, Soups, Meat,  info@tandoor-grill.com, Monday - Sunday 11:30...', score: 0.4409780793816068), context=None, document_offset=ExtractedAnswer.Span(start=95, end=112), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.005986463822949875, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "What are the opening days and hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8397794961929321, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 0.6269520563996132), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.791502058506012, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 0.6269520563996132), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.7872123718261719, data='Monday - Sunday', document=Document(id=0259c633d15088de015f32391e35593c62914f2ccdb89c3a878ba00cdd7887aa, content: 'Aqua Sport, Restaurant, Bar, Latin, Vegetarian, Cocktails, Pizza, Seafood, Fast Food, infoaquarestau...', score: 0.4185231070897296), context=None, document_offset=ExtractedAnswer.Span(start=117, end=132), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.007108308015874696, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "When is open the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.7865237593650818, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 0.6357605786058824), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.729029655456543, data='Monday - Sunday', document=Document(id=0259c633d15088de015f32391e35593c62914f2ccdb89c3a878ba00cdd7887aa, content: 'Aqua Sport, Restaurant, Bar, Latin, Vegetarian, Cocktails, Pizza, Seafood, Fast Food, infoaquarestau...', score: 0.4430885420666822), context=None, document_offset=ExtractedAnswer.Span(start=117, end=132), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.6936945915222168, data='Monday - Sunday', document=Document(id=637184d4f97a641e5450841a26086bdb9b51f5b3e9b3f063758848a598854252, content: 'Tandoor, Restaurant, Indian, Vegetarian, Soups, Meat,  info@tandoor-grill.com, Monday - Sunday 11:30...', score: 0.44214222169515693), context=None, document_offset=ExtractedAnswer.Span(start=79, end=94), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.017718460102356975, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %% [markdown]
# Try extracting some answers. Если подавать только description в качестве content, а остальное в качестве meta, работа алгоритма не очень. Не правильно определяются заведения.

# %% [markdown]
# В ходе тестов выявлено, что лучше всего подавать combined_text, это столбец, содержащий все данные со столбцов в одном.

# %% [markdown]
# Не идеально. Сейчас заведение определяется правильно, но режим работы почему то дробится. На дни недели и часы работы.

# %% [markdown]
# Если в контенте combined text, а также присутствует meta, результат аналогичный.

# %% [markdown]
# При использовании модели Roberta версии Large и Base, качество ответов неуд (не те заведения). Если в Roberta подвавать только описание, без остальных столбцов, то результат работы совсем плачевный
#
# Deberta Large и Base версии ответы неуд (не те заведения).
#
# Лучший результат у базовой модели multi-qa-mpnet-base-dot-v1. Попадает в заведения, но отвечает слишком буквально.
#
# Работа bert-base-cased-squad2 также неуд.
#
# Разницы в ответе между multi-qa-mpnet-base-dot-v1 и multi-qa-distilbert-dot-v1 и multi-qa-MiniLM-L6-dot-v1 нет.
#
# Если использовать sentence-transformers/msmarco-bert-base-dot-v5, то есть аналогичную (но побольше) модель берта, обученного на другом датасете, результат тот же. При использовании sentence-transformers/msmarco-distilbert-base-tas-b и msmarco-MiniLM-L12-cos-v5 результат тот же.
#
# По сути, хорошо матчит по названию sentence трансформеры. А отвечает Deberta (но не те заведения). Возможно стоит использовать 2 модели. Отложим пока и попробуем другие варианты по тюнингу алгоритма.

# %% [markdown]
# В частности использовать Part-of-speech tagging (POS-tagging) — это процесс, используемый в обработке естественного языка (NLP), который заключается в автоматическом определении и обозначении частей речи для каждого слова в тексте. Части речи включают такие категории, как существительные, глаголы, прилагательные, наречия и другие. POS-тегинг помогает понять синтаксическую структуру текста и часто используется в более сложных задачах NLP, таких как синтаксический разбор, анализ тональности и извлечение информации.
#
# Процесс POS-тегинга обычно включает следующие этапы:
#
# 1. **Токенизация**: Разделение текста на отдельные слова или токены.
#
# 2. **Тегирование**: Каждому токену присваивается соответствующая часть речи. Это может быть сделано с помощью предварительно обученных моделей, которые используют вероятностные методы, такие как скрытые марковские модели (HMM), или современные подходы, такие как нейронные сети и трансформеры.
#
# 3. **Контекстное определение**: Поскольку некоторые слова могут принадлежать к нескольким частям речи в зависимости от контекста (например, слово «run» может быть как существительным, так и глаголом), алгоритмы POS-тегинга учитывают ближайшее окружение слова.
#
# POS-тегинг важен для более глубокого понимания текста и является основой для многих других приложений в области обработки естественного языка.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
def pos_tagging(text):
    doc = nlp(text)
    return [(token.text, token.pos_) for token in doc]

def create_document(row):
    content = row['combined_text']
    pos_tags = pos_tagging(content)
    return Document(content=content, meta={'pos_tags': pos_tags})

documents = [
    create_document(row)
    for _, row in df_for_LLM.iterrows()
]

# %%
documents
# Out:
# [Document(id=e79d09a1ec1d9c3a8f4f558b9590369d0e0f0e3e5bd3c9705e33725fbec9f19f, content: 'San Carlos, Hardware Store, mmora@depositosancarlos.com, Monday - Friday 7:00 AM- 5:00 PM, Saturday ...', meta: {'pos_tags': [('San', 'PROPN'), ('Carlos', 'PROPN'), (',', 'PUNCT'), ('Hardware', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), ('mmora@depositosancarlos.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('7:00', 'NUM'), ('AM-', 'PROPN'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('7:00', 'NUM'), ('AM-', 'PROPN'), ('3:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('Сlosed', 'VERB'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Deposito', 'PROPN'), ('San', 'PROPN'), ('Carlos', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('largest', 'ADJ'), ('building', 'NOUN'), ('materials', 'NOUN'), ('store', 'NOUN'), ('with', 'ADP'), ('a', 'DET'), ('strong', 'ADJ'), ('presence', 'NOUN'), ('in', 'ADP'), ('Guanacaste', 'PROPN'), ('since', 'SCONJ'), ('1994', 'NUM'), ('.', 'PUNCT'), ('Starting', 'VERB'), ('as', 'ADP'), ('a', 'DET'), ('small', 'ADJ'), ('wood', 'NOUN'), ('depot', 'NOUN'), (',', 'PUNCT'), ('it', 'PRON'), ('has', 'AUX'), ('expanded', 'VERB'), ('to', 'ADP'), ('multiple', 'ADJ'), ('branches', 'NOUN'), (',', 'PUNCT'), ('providing', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('construction', 'NOUN'), ('materials', 'NOUN'), ('and', 'CCONJ'), ('expert', 'NOUN'), ('advice', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Services', 'NOUN'), (':', 'PUNCT'), ('Paint', 'PROPN'), ('consultations', 'NOUN'), (',', 'PUNCT'), ('material', 'ADJ'), ('sales', 'NOUN'), (',', 'PUNCT'), ('delivery', 'NOUN'), ('fleet', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Experienced', 'VERB'), ('staff', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2670', 'NUM'), ('-', 'SYM'), ('1211', 'NUM')]}),
#  Document(id=99693d64bb133cf538a263d7df3120483214c471a0a5927e389a416f831948e6, content: 'Angel's salon, Beauty Bar, myrnaangel@hotmail.com, Monday 9:00 AM - 6:00 PM, Tuesday - Saturday 9:00...', meta: {'pos_tags': [('Angel', 'PROPN'), ("'s", 'PART'), ('salon', 'NOUN'), (',', 'PUNCT'), ('Beauty', 'PROPN'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('myrnaangel@hotmail.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('6:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Tuesday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('-', 'PUNCT'), ('Сlosed', 'VERB'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Angel', 'PROPN'), ("'s", 'PART'), ('Salon', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('professional', 'ADJ'), ('hair', 'NOUN'), ('and', 'CCONJ'), ('beauty', 'NOUN'), ('salon', 'NOUN'), (' ', 'SPACE'), ('with', 'ADP'), ('19', 'NUM'), ('years', 'NOUN'), ('of', 'ADP'), ('experience', 'NOUN'), ('.', 'PUNCT'), ('Offers', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('services', 'NOUN'), ('for', 'ADP'), ('men', 'NOUN'), (',', 'PUNCT'), ('women', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('children', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Hair', 'NOUN'), ('coloring', 'VERB'), ('and', 'CCONJ'), ('extensions', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Manicure', 'NOUN'), ('and', 'CCONJ'), ('pedicure', 'NOUN'), ('services', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Eyelash', 'PROPN'), ('extensions', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Professional', 'ADJ'), ('products', 'NOUN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=17056d1a70e5cdffa013fd797246fbd8e57336afa1ca6b6ae833c32280c72916, content: 'La Casa del Plastico, Department Store, info@lacasadelplastico.com, Monday - Saturday 8:00 AM - 6:00...', meta: {'pos_tags': [('La', 'PROPN'), ('Casa', 'PROPN'), ('del', 'PROPN'), ('Plastico', 'PROPN'), (',', 'PUNCT'), ('Department', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), ('info@lacasadelplastico.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('6:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('La', 'PROPN'), ('Casa', 'PROPN'), ('del', 'PROPN'), ('Plastico', 'PROPN'), ('specializes', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('sale', 'NOUN'), ('of', 'ADP'), ('products', 'NOUN'), ('for', 'ADP'), ('home', 'NOUN'), (',', 'PUNCT'), ('primary', 'ADJ'), ('food', 'NOUN'), ('industry', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('commerce', 'PROPN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2670', 'NUM'), ('-', 'SYM'), ('0700', 'NUM')]}),
#  Document(id=3bfddb004e7edf3a9d0c9cc70777675f3b8a72c9b4500418d31bb0148b836902, content: 'EPA Solarium, Department Store, Hardware Store, contacto@xr.epa.biz, Monday - Friday 9:00 AM - 5:00 ...', meta: {'pos_tags': [('EPA', 'PROPN'), ('Solarium', 'PROPN'), (',', 'PUNCT'), ('Department', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), ('Hardware', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), ('contacto@xr.epa.biz', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('3:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('closed', 'VERB'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('EPA', 'PROPN'), ('Solarium', 'PROPN'), ('-', 'PUNCT'), ('Hardware', 'PROPN'), ('and', 'CCONJ'), ('Home', 'PROPN'), ('Goods', 'PROPN'), ('Store', 'PROPN'), ('offers', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('selection', 'NOUN'), ('of', 'ADP'), ('building', 'NOUN'), ('materials', 'NOUN'), (',', 'PUNCT'), ('furniture', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('home', 'NOUN'), ('improvement', 'NOUN'), ('products', 'NOUN'), ('.', 'PUNCT'), ('Еру', 'NOUN'), ('store', 'NOUN'), ('provides', 'VERB'), ('everything', 'PRON'), ('needed', 'VERB'), ('for', 'ADP'), ('construction', 'NOUN'), (',', 'PUNCT'), ('decoration', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('renovation', 'NOUN'), ('projects', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Building', 'NOUN'), ('materials', 'NOUN'), ('and', 'CCONJ'), ('finishes', 'VERB'), ('\n', 'SPACE'), ('•', 'NUM'), ('Furniture', 'NOUN'), ('and', 'CCONJ'), ('home', 'NOUN'), ('decor', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Lighting', 'NOUN'), ('and', 'CCONJ'), ('garden', 'NOUN'), ('supplies', 'NOUN'), ('\n', 'SPACE'), ('•', 'X'), ('Automotive', 'PROPN'), ('and', 'CCONJ'), ('tools', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Wood', 'PROPN'), ('and', 'CCONJ'), ('paint', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Appliances', 'PROPN'), ('and', 'CCONJ'), ('bathroom', 'NOUN'), ('fixtures', 'NOUN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=4e04ba745cf19a8ea67ca52c456f89f4234a13158428309373448ab85f2d5c90, content: 'Policia Upala, Police Department, Information Services, no information available, Monday - Friday 8:...', meta: {'pos_tags': [('Policia', 'PROPN'), ('Upala', 'PROPN'), (',', 'PUNCT'), ('Police', 'PROPN'), ('Department', 'PROPN'), (',', 'PUNCT'), ('Information', 'PROPN'), ('Services', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('4:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Canalete', 'PROPN'), (',', 'PUNCT'), ('Policia', 'PROPN'), ('Upala', 'PROPN'), ('-', 'PUNCT'), ('Police', 'PROPN'), ('Department', 'PROPN'), ('and', 'CCONJ'), ('Information', 'PROPN'), ('Services', 'PROPN'), ('provides', 'VERB'), ('essential', 'ADJ'), ('public', 'ADJ'), ('safety', 'NOUN'), ('services', 'NOUN'), ('and', 'CCONJ'), ('handles', 'VERB'), ('regional', 'ADJ'), ('documentation', 'NOUN'), ('processes', 'NOUN'), ('.', 'PUNCT'), ('Fingerprinting', 'NOUN'), ('services', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('available', 'ADJ'), ('at', 'ADP'), ('this', 'DET'), ('location', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Fingerprinting', 'PROPN'), ('services', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Regional', 'ADJ'), ('documentation', 'NOUN'), ('and', 'CCONJ'), ('paperwork', 'NOUN'), ('assistance', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Public', 'ADJ'), ('safety', 'NOUN'), ('and', 'CCONJ'), ('community', 'NOUN'), ('support', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2470', 'NUM'), ('-', 'SYM'), ('0235', 'NUM')]}),
#  Document(id=01efcfd52e5002213278f1b293c69ef0fc4d645d66708f0c54bd8d11eec725bd, content: 'Drive, Car Repair, Motorcycle Repair, Electric Vehicle Repair, drivecococr@gmail.com, Monday - Frida...', meta: {'pos_tags': [('Drive', 'VERB'), (',', 'PUNCT'), ('Car', 'PROPN'), ('Repair', 'PROPN'), (',', 'PUNCT'), ('Motorcycle', 'PROPN'), ('Repair', 'PROPN'), (',', 'PUNCT'), ('Electric', 'PROPN'), ('Vehicle', 'PROPN'), ('Repair', 'PROPN'), (',', 'PUNCT'), ('drivecococr@gmail.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Drive', 'PROPN'), ('is', 'AUX'), ('an', 'DET'), ('auto', 'NOUN'), ('service', 'NOUN'), ('center', 'NOUN'), ('in', 'ADP'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('specializing', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('\xa0', 'SPACE'), ('repair', 'NOUN'), ('\xa0', 'SPACE'), ('and', 'CCONJ'), ('\xa0', 'SPACE'), ('maintenance', 'NOUN'), ('\xa0', 'SPACE'), ('of', 'ADP'), ('cars', 'NOUN'), (',', 'PUNCT'), ('motorcycles', 'NOUN'), (',', 'PUNCT'), ('electric', 'ADJ'), ('vehicles', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('special', 'ADJ'), ('equipment', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Our', 'PRON'), ('mechanics', 'NOUN'), ('and', 'CCONJ'), ('specialists', 'NOUN'), ('are', 'AUX'), ('top', 'ADJ'), ('-', 'PUNCT'), ('notch', 'NOUN'), (',', 'PUNCT'), ('bringing', 'VERB'), ('\xa0', 'SPACE'), ('European', 'ADJ'), ('expertise', 'NOUN'), ('\xa0', 'SPACE'), ('to', 'ADP'), ('every', 'DET'), ('job', 'NOUN'), ('.', 'PUNCT'), ('Drive', 'NOUN'), ('is', 'AUX'), ('dedicated', 'VERB'), ('to', 'ADP'), ('ensuring', 'VERB'), ('the', 'DET'), ('highest', 'ADJ'), ('quality', 'NOUN'), ('service', 'NOUN'), ('and', 'CCONJ'), ('customer', 'NOUN'), ('satisfaction', 'NOUN'), ('with', 'ADP'), ('a', 'DET'), ('\xa0', 'SPACE'), ('lifetime', 'NOUN'), ('warranty', 'NOUN'), ('\xa0', 'SPACE'), ('on', 'ADP'), ('our', 'PRON'), ('workmanship', 'NOUN'), ('.', 'PUNCT'), ('Parts', 'NOUN'), ('can', 'AUX'), ('be', 'AUX'), ('ordered', 'VERB'), ('by', 'ADP'), ('us', 'PRON'), ('or', 'CCONJ'), ('brought', 'VERB'), ('in', 'ADP'), ('by', 'ADP'), ('customers', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('team', 'NOUN'), ('comprises', 'VERB'), ('only', 'ADV'), ('the', 'DET'), ('\xa0', 'SPACE'), ('best', 'ADJ'), ('professionals', 'NOUN'), ('in', 'ADP'), ('their', 'PRON'), ('field', 'NOUN'), (',', 'PUNCT'), ('ensuring', 'VERB'), ('every', 'DET'), ('job', 'NOUN'), ('is', 'AUX'), ('done', 'VERB'), ('to', 'ADP'), ('the', 'DET'), ('highest', 'ADJ'), ('standards', 'NOUN'), ('.', 'PUNCT'), ('With', 'ADP'), ('extensive', 'ADJ'), ('experience', 'NOUN'), ('dating', 'VERB'), ('back', 'ADV'), ('to', 'ADP'), ('2000', 'NUM'), (',', 'PUNCT'), ('the', 'DET'), ('team', 'NOUN'), ('brings', 'VERB'), ('a', 'DET'), ('wealth', 'NOUN'), ('of', 'ADP'), ('\xa0', 'SPACE'), ('knowledge', 'NOUN'), ('\xa0', 'SPACE'), ('and', 'CCONJ'), ('\xa0', 'SPACE'), ('dedication', 'NOUN'), ('\xa0', 'SPACE'), ('to', 'ADP'), ('the', 'DET'), ('business', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=df5b4415f1dc93cc36b1aa84cb73268ece2b068a3af38aa19af045b982344a05, content: 'Dual, Post Office, Delivery, servicioalcliente@dualservicioscr.com, Monday - Friday 9:00 AM - 6:00 P...', meta: {'pos_tags': [('Dual', 'ADJ'), (',', 'PUNCT'), ('Post', 'PROPN'), ('Office', 'PROPN'), (',', 'PUNCT'), ('Delivery', 'PROPN'), (',', 'PUNCT'), ('servicioalcliente@dualservicioscr.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('6:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('lunch', 'NOUN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('12:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('2:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('lunch', 'NOUN'), ('12:00', 'NUM'), ('PM-', 'PROPN'), ('12:30', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('closed', 'VERB'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Dual', 'PROPN'), ('offers', 'VERB'), ('commercial', 'ADJ'), ('mail', 'NOUN'), ('services', 'NOUN'), ('for', 'ADP'), ('shipments', 'NOUN'), ('within', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), ('and', 'CCONJ'), ('from', 'ADP'), ('the', 'DET'), ('USA', 'PROPN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Services', 'NOUN'), ('include', 'VERB'), ('receiving', 'VERB'), ('packages', 'NOUN'), ('from', 'ADP'), ('Florida', 'PROPN'), (',', 'PUNCT'), ('customs', 'PROPN'), ('clearance', 'NOUN'), (',', 'PUNCT'), ('cost', 'NOUN'), ('estimation', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('consultations', 'NOUN'), ('via', 'ADP'), ('WhatsApp', 'PROPN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Locker', 'PROPN'), ('services', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Purchasing', 'NOUN'), ('advice', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Quotes', 'PROPN'), ('for', 'ADP'), ('purchases', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Shopping', 'NOUN'), ('assistance', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Package', 'PROPN'), ('delivery', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2249', 'NUM'), ('-', 'SYM'), ('6262', 'NUM')]}),
#  Document(id=f550d4445d2184df1cb1f1e63886335f7dce6455869d48da9fce4c7f47711634, content: 'Full market, Supermarket, no information available, Monday - Sunday Everyday 24/7, Liberia, Full Mar...', meta: {'pos_tags': [('Full', 'ADJ'), ('market', 'NOUN'), (',', 'PUNCT'), ('Supermarket', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('Everyday', 'PROPN'), ('24/7', 'PROPN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Full', 'PROPN'), ('Market', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('convenience', 'NOUN'), ('store', 'NOUN'), ('located', 'VERB'), ('at', 'ADP'), ('a', 'DET'), ('gas', 'NOUN'), ('station', 'NOUN'), ('where', 'SCONJ'), ('you', 'PRON'), ('can', 'AUX'), ('buy', 'VERB'), ('snacks', 'NOUN'), (',', 'PUNCT'), ('drinks', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('coffee', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('It', 'PRON'), ('also', 'ADV'), ('offers', 'VERB'), ('seating', 'VERB'), ('areas', 'NOUN'), ('for', 'ADP'), ('a', 'DET'), ('quick', 'ADJ'), ('bite', 'NOUN'), ('or', 'CCONJ'), ('coffee', 'NOUN'), ('break', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'PROPN'), ('Sells', 'NOUN'), (' ', 'SPACE'), ('beverages', 'NOUN'), ('\n', 'SPACE'), ('•', 'X'), ('Provides', 'VERB'), ('tables', 'NOUN'), ('for', 'ADP'), ('seating', 'NOUN'), ('\n', 'SPACE'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=70a758757077ca1182c0cfd042049c6519fc36452b2017ca081f2b5f335e1303, content: 'Maxi Pali, Supermarket, sac@wal-mart.com, Monday -  Friday 8:00 AM - 8:00 PM,
#  Saturday 9:00 AM - 8:0...', meta: {'pos_tags': [('Maxi', 'PROPN'), ('Pali', 'PROPN'), (',', 'PUNCT'), ('Supermarket', 'PROPN'), (',', 'PUNCT'), ('sac@wal-mart.com', 'NUM'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), (' ', 'SPACE'), ('Friday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('8:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('\n', 'SPACE'), ('Saturday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('8:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('\n', 'SPACE'), ('Sunday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('18:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Maxi', 'PROPN'), ('Pali', 'PROPN'), ('is', 'AUX'), ('onestop', 'ADJ'), ('destination', 'NOUN'), ('for', 'ADP'), ('groceries', 'NOUN'), (',', 'PUNCT'), ('electronics', 'NOUN'), (',', 'PUNCT'), ('home', 'NOUN'), ('goods', 'NOUN'), (',', 'PUNCT'), ('children', 'NOUN'), ("'s", 'PART'), ('products', 'NOUN'), (',', 'PUNCT'), ('sport', 'NOUN'), ('goods', 'NOUN'), (',', 'PUNCT'), ('clothing', 'NOUN'), (',', 'PUNCT'), ('pet', 'ADJ'), ('products', 'NOUN'), ('and', 'CCONJ'), ('vehicles', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Maxi', 'PROPN'), ('Pali', 'PROPN'), ('offers', 'VERB'), ('convenience', 'NOUN'), ('and', 'CCONJ'), ('affordability', 'NOUN'), ('for', 'ADP'), ('all', 'DET'), ('your', 'PRON'), ('shopping', 'NOUN'), ('needs', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('800', 'NUM'), ('-', 'SYM'), ('8000', 'NUM'), ('-', 'SYM'), ('722', 'NUM')]}),
#  Document(id=89775a94fe665263cf3b8185ae4419190e92ae2b6648a160be8db7faa2e1b043, content: 'Fraiche, Perfume Store, Speciality & Gift Shops, info@fraiche.co.cr, Monday  - Sunday 9:00 AM - 6:00...', meta: {'pos_tags': [('Fraiche', 'PROPN'), (',', 'PUNCT'), ('Perfume', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), ('Speciality', 'PROPN'), ('&', 'CCONJ'), ('Gift', 'PROPN'), ('Shops', 'PROPN'), (',', 'PUNCT'), ('info@fraiche.co.cr', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), (' ', 'SPACE'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('6:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), (' ', 'SPACE'), ('lunch', 'NOUN'), ('11:30', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('12:30', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Fraiche', 'PROPN'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('shop', 'NOUN'), ('specializing', 'VERB'), ('in', 'ADP'), ('perfumes', 'NOUN'), (',', 'PUNCT'), ('cosmetics', 'NOUN'), (',', 'PUNCT'), ('personal', 'ADJ'), ('care', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('aromatherapy', 'NOUN'), ('products', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('It', 'PRON'), ('offers', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('high', 'ADJ'), ('-', 'PUNCT'), ('quality', 'NOUN'), ('items', 'NOUN'), ('to', 'PART'), ('enhance', 'VERB'), ('your', 'PRON'), ('beauty', 'NOUN'), ('and', 'CCONJ'), ('well', 'NOUN'), ('-', 'PUNCT'), ('being', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Wide', 'ADJ'), ('selection', 'NOUN'), ('of', 'ADP'), ('perfumes', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('High', 'ADJ'), ('-', 'PUNCT'), ('quality', 'NOUN'), ('cosmetics', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Personal', 'ADJ'), ('care', 'NOUN'), ('products', 'NOUN'), ('\n', 'SPACE'), ('•', 'X'), ('Aromatherapy', 'PROPN'), ('items', 'NOUN'), (',', 'PUNCT'), ('+506', 'NOUN'), ('2248', 'NUM'), ('-', 'SYM'), ('9796', 'NUM')]}),
#  Document(id=a26509087304c3ebefe32d7c338e85ad8b1ee549c3407248899270dcf3d61ed8, content: 'Jiron, Bed Shop, liberia@jiron.com, Monday - Saturday 9:00 AM - 7:00 PM, Sunday  9:00 AM - 5:00 PM, ...', meta: {'pos_tags': [('Jiron', 'PROPN'), (',', 'PUNCT'), ('Bed', 'PROPN'), ('Shop', 'PROPN'), (',', 'PUNCT'), ('liberia@jiron.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('7:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Jiron', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('specialty', 'NOUN'), ('store', 'NOUN'), ('focused', 'VERB'), ('on', 'ADP'), ('providing', 'VERB'), ('the', 'DET'), ('best', 'ADJ'), ('mattresses', 'NOUN'), ('in', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), ('at', 'ADP'), ('competitive', 'ADJ'), ('prices', 'NOUN'), ('.', 'PUNCT'), ('Experience', 'VERB'), ('the', 'DET'), ('magic', 'NOUN'), ('of', 'ADP'), ('quality', 'NOUN'), ('sleep', 'NOUN'), ('with', 'ADP'), ('Jiron', 'PROPN'), ("'s", 'PART'), ('trusted', 'ADJ'), ('products', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Mattresses', 'PROPN'), ('and', 'CCONJ'), ('box', 'NOUN'), ('springs', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Wholesale', 'PROPN'), ('and', 'CCONJ'), ('retail', 'ADJ'), ('mattress', 'NOUN'), ('sales', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('120', 'NUM'), ('years', 'NOUN'), ('of', 'ADP'), ('experience', 'NOUN'), ('in', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=1a56fbfa3e21351cc91f7d2014085ed57d08595ab86bbdb644b5b6892a6c37a9, content: 'Ekono, Department Store, info@ekonocr.com, Monday - Saturday  8:30 AM - 8:00 PM, Sunday  9:00 AM - 5...', meta: {'pos_tags': [('Ekono', 'PROPN'), (',', 'PUNCT'), ('Department', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), ('info@ekonocr.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), (' ', 'SPACE'), ('8:30', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('8:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Ekono', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('leading', 'VERB'), ('department', 'NOUN'), ('store', 'NOUN'), ('in', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), (',', 'PUNCT'), ('offering', 'VERB'), ('the', 'DET'), ('latest', 'ADJ'), ('fashion', 'NOUN'), ('for', 'ADP'), ('women', 'NOUN'), (',', 'PUNCT'), ('men', 'NOUN'), (',', 'PUNCT'), ('children', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('babies', 'NOUN'), (',', 'PUNCT'), ('along', 'ADP'), ('with', 'ADP'), ('footwear', 'NOUN'), ('and', 'CCONJ'), ('accessories', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('store', 'NOUN'), ('aims', 'VERB'), ('to', 'PART'), ('improve', 'VERB'), ('the', 'DET'), ('quality', 'NOUN'), ('of', 'ADP'), ('life', 'NOUN'), ('for', 'ADP'), ('Costa', 'ADJ'), ('Rican', 'ADJ'), ('families', 'NOUN'), ('by', 'ADP'), ('providing', 'VERB'), ('affordable', 'ADJ'), ('products', 'NOUN'), ('and', 'CCONJ'), ('a', 'DET'), ('pleasant', 'ADJ'), ('shopping', 'NOUN'), ('experience', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('clothing', 'NOUN'), ('for', 'ADP'), ('all', 'DET'), ('ages', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Home', 'PROPN'), ('decor', 'NOUN'), (',', 'PUNCT'), ('health', 'NOUN'), (',', 'PUNCT'), ('beauty', 'NOUN'), ('products', 'NOUN'), (',', 'PUNCT'), ('toys', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('In', 'ADP'), ('-', 'PUNCT'), ('store', 'NOUN'), ('pharmacy', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2666', 'NUM'), ('-', 'SYM'), ('8117', 'NUM')]}),
#  Document(id=b7ce9a8691b2aed04ba87d1b0f76988b4b7390843212267f98b389181eaa2219, content: 'Baruch, Barbershop, no information available, Monday - Sunday  7:30 AM- 8:00 PM, Playa Ocotal, Baruc...', meta: {'pos_tags': [('Baruch', 'ADJ'), (',', 'PUNCT'), ('Barbershop', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('7:30', 'NUM'), ('AM-', 'PROPN'), ('8:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('Ocotal', 'PROPN'), (',', 'PUNCT'), ('Baruch', 'PROPN'), ('Barber', 'PROPN'), ('Shop', 'PROPN'), ('offers', 'VERB'), ('top', 'ADJ'), ('-', 'PUNCT'), ('notch', 'NOUN'), ('hairdressing', 'NOUN'), ('services', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('comfortable', 'ADJ'), ('setting', 'NOUN'), ('.', 'PUNCT'), ('\xa0\n\n', 'SPACE'), ('Specializing', 'VERB'), ('in', 'ADP'), ('precision', 'NOUN'), ('men', 'NOUN'), ("'s", 'PART'), ('haircuts', 'NOUN'), (',', 'PUNCT'), ('classic', 'ADJ'), ('shaves', 'VERB'), (',', 'PUNCT'), ('beard', 'NOUN'), ('trimming', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('styling', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('6169', 'NUM'), ('-', 'SYM'), ('5523', 'NUM')]}),
#  Document(id=e9a5305c9b4e48afc146b0de2c1418a77c98ec1e4204c623e0ccd2de877f5c7d, content: 'Costa Doc, Medical Services, info@costadoc.com, Monday - Sunday Open 24 hours, Playa del Coco, Costa...', meta: {'pos_tags': [('Costa', 'PROPN'), ('Doc', 'PROPN'), (',', 'PUNCT'), ('Medical', 'PROPN'), ('Services', 'PROPN'), (',', 'PUNCT'), ('info@costadoc.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('Open', 'PROPN'), ('24', 'NUM'), ('hours', 'NOUN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Costa', 'PROPN'), ('Doc', 'PROPN'), ('offers', 'VERB'), ('comprehensive', 'ADJ'), ('medical', 'ADJ'), ('services', 'NOUN'), (',', 'PUNCT'), ('assisting', 'VERB'), ('with', 'ADP'), ('all', 'DET'), ('major', 'ADJ'), ('medical', 'ADJ'), ('conditions', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('office', 'NOUN'), ('philosophy', 'NOUN'), ('focuses', 'VERB'), ('on', 'ADP'), ('evaluating', 'VERB'), ('your', 'PRON'), ('health', 'NOUN'), ('status', 'NOUN'), ('and', 'CCONJ'), ('working', 'VERB'), ('with', 'ADP'), ('your', 'PRON'), ('clinical', 'ADJ'), ('background', 'NOUN'), ('to', 'PART'), ('avoid', 'VERB'), ('unnecessary', 'ADJ'), ('procedures', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Medical', 'ADJ'), ('services', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Emphasis', 'PROPN'), ('on', 'ADP'), ('evaluating', 'VERB'), ('health', 'NOUN'), ('status', 'NOUN'), ('first', 'ADJ'), ('\n', 'SPACE'), ('•', 'X'), ('Minimizing', 'VERB'), ('unnecessary', 'ADJ'), ('procedures', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8808', 'NUM'), ('-', 'SYM'), ('8111', 'NUM')]}),
#  Document(id=c329f11d54fe23438f14d00e2257d83db5725ce90ace23c024b1bf2b7fdddbce, content: 'Guiselle Rivera, Speciality & Gift Shops, guiselleriveracr@gmail.com, Monday - Saturday 10:00 AM - 7...', meta: {'pos_tags': [('Guiselle', 'PROPN'), ('Rivera', 'PROPN'), (',', 'PUNCT'), ('Speciality', 'PROPN'), ('&', 'CCONJ'), ('Gift', 'PROPN'), ('Shops', 'PROPN'), (',', 'PUNCT'), ('guiselleriveracr@gmail.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('10:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('7:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('-', 'PUNCT'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Guiselle', 'PROPN'), ('Rivera', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('designer', 'NOUN'), ('and', 'CCONJ'), ('handcrafter', 'NOUN'), ('offering', 'VERB'), ('unique', 'ADJ'), ('jewelry', 'NOUN'), ('and', 'CCONJ'), ('accessories', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Located', 'VERB'), ('in', 'ADP'), ('Playas', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), ("'s", 'PART'), ('Comercial', 'PROPN'), ('Center', 'PROPN'), ('Pueblito', 'PROPN'), ('Sur', 'PROPN'), (',', 'PUNCT'), ('this', 'DET'), ('store', 'NOUN'), ('also', 'ADV'), ('specializes', 'VERB'), ('in', 'ADP'), ('natural', 'ADJ'), ('cosmetics', 'NOUN'), ('for', 'ADP'), ('enhanced', 'VERB'), ('well', 'NOUN'), ('-', 'PUNCT'), ('being', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Unique', 'ADJ'), ('handmade', 'ADJ'), ('jewelry', 'NOUN'), ('and', 'CCONJ'), ('accessories', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Natural', 'ADJ'), ('cosmetics', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Conveniently', 'ADV'), ('located', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('Commercial', 'PROPN'), ('Center', 'PROPN'), ('Pueblito', 'PROPN'), ('Sur', 'PROPN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Friendly', 'ADJ'), ('and', 'CCONJ'), ('welcoming', 'VERB'), ('atmosphere', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Excellent', 'PROPN'), ('prices', 'NOUN'), ('\n\n', 'SPACE'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=ad102c0132d9bfaf61316bca77a8ea9b3d21026ecfa54a1468610385b29f809c, content: 'Los Mangos 2, Supermarket, no information available, Monday - Sunday 8:00 AM - 9:00 PM, Playa Ocotal...', meta: {'pos_tags': [('Los', 'PROPN'), ('Mangos', 'PROPN'), ('2', 'NUM'), (',', 'PUNCT'), ('Supermarket', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('9:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('Ocotal', 'PROPN'), (',', 'PUNCT'), ('Los', 'PROPN'), ('Mangos', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('Chinese', 'ADJ'), ('store', 'NOUN'), ('with', 'ADP'), ('a', 'DET'), ('wide', 'ADJ'), ('assortment', 'NOUN'), ('of', 'ADP'), ('products', 'NOUN'), (',', 'PUNCT'), ('including', 'VERB'), ('groceries', 'NOUN'), (',', 'PUNCT'), ('household', 'NOUN'), ('items', 'NOUN'), (',', 'PUNCT'), ('automotive', 'ADJ'), ('supplies', 'NOUN'), (',', 'PUNCT'), ('small', 'ADJ'), ('appliances', 'NOUN'), (',', 'PUNCT'), ('personal', 'ADJ'), ('hygiene', 'NOUN'), ('products', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('children', 'NOUN'), ("'s", 'PART'), ('items', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('It', 'PRON'), ('offers', 'VERB'), ('a', 'DET'), ('good', 'ADJ'), ('selection', 'NOUN'), ('of', 'ADP'), ('products', 'NOUN'), ('at', 'ADP'), ('reasonable', 'ADJ'), ('prices', 'NOUN'), (',', 'PUNCT'), ('often', 'ADV'), ('cheaper', 'ADJ'), ('than', 'ADP'), ('larger', 'ADJ'), ('supermarkets', 'NOUN'), ('.', 'PUNCT'), ('\n', 'SPACE'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=9001631b6575b0f0e17f3198fa5468ee6e1be1c93492e0892457184dce984b2a, content: 'Gas station Full, Gas Station, Gasoline, katarsis.obl@gmail.com, Monday - Sunday Open 24 hours, no i...', meta: {'pos_tags': [('Gas', 'NOUN'), ('station', 'NOUN'), ('Full', 'ADJ'), (',', 'PUNCT'), ('Gas', 'PROPN'), ('Station', 'PROPN'), (',', 'PUNCT'), ('Gasoline', 'PROPN'), (',', 'PUNCT'), ('katarsis.obl@gmail.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('Open', 'PROPN'), ('24', 'NUM'), ('hours', 'NOUN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Convenient', 'ADJ'), ('gas', 'NOUN'), ('station', 'NOUN'), ('with', 'ADP'), ('a', 'DET'), ('mini', 'NOUN'), ('-', 'NOUN'), ('market', 'NOUN'), ('and', 'CCONJ'), ('cafeteria', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Minimarket', 'PROPN'), ('and', 'CCONJ'), ('cafe', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Diesel', 'PROPN'), ('fuel', 'NOUN'), (' ', 'SPACE'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=2f90a6d9e72a6faa6c85cb21ffd4bbaffc76be3e16e8956bcd39e275d3480022, content: 'M&M (Rambutan Restaurante), Restaurant, International, Coffee, Desserts, Meat, cesarilama@yahoo.es, ...', meta: {'pos_tags': [('M&M', 'PROPN'), ('(', 'PUNCT'), ('Rambutan', 'PROPN'), ('Restaurante', 'PROPN'), (')', 'PUNCT'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Coffee', 'PROPN'), (',', 'PUNCT'), ('Desserts', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('cesarilama@yahoo.es', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('7:00', 'NUM'), ('am', 'NOUN'), ('-', 'PUNCT'), ('8:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Tuesday', 'PROPN'), ('-', 'PUNCT'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Wednesday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('7:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('8:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('At', 'ADP'), ('Rambutan', 'PROPN'), ('Cafe', 'PROPN'), (',', 'PUNCT'), ('located', 'VERB'), ('within', 'ADP'), ('the', 'DET'), ('M&M', 'PROPN'), ('Beach', 'PROPN'), ('House', 'PROPN'), ('Hotel', 'PROPN'), (',', 'PUNCT'), ('you', 'PRON'), ('can', 'AUX'), ('enjoy', 'VERB'), ('breakfast', 'NOUN'), (',', 'PUNCT'), ('lunch', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('dinner', 'NOUN'), ('options', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('menu', 'NOUN'), ('includes', 'VERB'), ('a', 'DET'), ('variety', 'NOUN'), ('of', 'ADP'), ('dishes', 'NOUN'), ('catering', 'VERB'), ('to', 'ADP'), ('both', 'DET'), ('Costa', 'ADJ'), ('Rican', 'ADJ'), ('and', 'CCONJ'), ('American', 'ADJ'), ('tastes', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Coffee', 'PROPN'), (',', 'PUNCT'), ('Smoothies', 'PROPN'), (',', 'PUNCT'), ('Lemonade', 'PROPN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('Milkshakes', 'PROPN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Vegetarian', 'ADJ'), ('options', 'NOUN'), ('\n\n\n\n\n', 'SPACE'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=3e69f5bda127b027b9ce69367900e778f62a0fa69fa48807b8dfcd65c7cebb8e, content: 'Banco BCT, Bank, ATM, info@corporacionbct.com
#  atencionalclientebct@corporacionbct.com, Monday - Frid...', meta: {'pos_tags': [('Banco', 'PROPN'), ('BCT', 'PROPN'), (',', 'PUNCT'), ('Bank', 'PROPN'), (',', 'PUNCT'), ('ATM', 'PROPN'), (',', 'PUNCT'), ('info@corporacionbct.com', 'X'), ('\n', 'SPACE'), ('atencionalclientebct@corporacionbct.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('4:30', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Comunidad', 'PROPN'), (',', 'PUNCT'), ('BCT', 'PROPN'), ('Bank', 'PROPN'), ('branch', 'NOUN'), ('in', 'ADP'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), ('offers', 'VERB'), ('comprehensive', 'ADJ'), ('banking', 'NOUN'), ('services', 'NOUN'), ('to', 'PART'), ('meet', 'VERB'), ('the', 'DET'), ('needs', 'NOUN'), ('of', 'ADP'), ('both', 'DET'), ('individuals', 'NOUN'), ('and', 'CCONJ'), ('businesses', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('With', 'ADP'), ('a', 'DET'), ('focus', 'NOUN'), ('on', 'ADP'), ('customer', 'NOUN'), ('well', 'NOUN'), ('-', 'PUNCT'), ('being', 'NOUN'), ('and', 'CCONJ'), ('safety', 'NOUN'), (',', 'PUNCT'), ('the', 'DET'), ('branch', 'NOUN'), ('provides', 'VERB'), ('personal', 'ADJ'), ('banking', 'NOUN'), (',', 'PUNCT'), ('business', 'NOUN'), ('banking', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('estate', 'NOUN'), ('banking', 'NOUN'), ('solutions', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), (',', 'PUNCT'), ('+506', 'NOUN'), ('2667', 'NUM'), ('-', 'SYM'), ('1012', 'NUM')]}),
#  Document(id=c624edf167cbf49cf8685f177ada1eb1cb8e0a128315cb1097e71ceb61d2f933, content: 'El Lagar Do It Center, Hardware Store,  lagarenlinea@ellagar.com, Monday - Friday 7:00 AM - 6:00 PM,...', meta: {'pos_tags': [('El', 'PROPN'), ('Lagar', 'PROPN'), ('Do', 'AUX'), ('It', 'PRON'), ('Center', 'VERB'), (',', 'PUNCT'), ('Hardware', 'PROPN'), ('Store', 'PROPN'), (',', 'PUNCT'), (' ', 'SPACE'), ('lagarenlinea@ellagar.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('7:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('6:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('7:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('1:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('El', 'PROPN'), ('\xa0', 'SPACE'), ('Lagar', 'PROPN'), ('\xa0', 'SPACE'), ('is', 'AUX'), ('\xa0', 'SPACE'), ('a', 'DET'), ('\xa0', 'SPACE'), ('large', 'ADJ'), ('\xa0', 'SPACE'), ('hypermarket', 'NOUN'), ('\xa0', 'SPACE'), ('that', 'PRON'), ('\xa0', 'SPACE'), ('specializes', 'VERB'), ('\xa0', 'SPACE'), ('in', 'ADP'), ('\xa0', 'SPACE'), ('building', 'NOUN'), ('\xa0', 'SPACE'), ('and', 'CCONJ'), ('\xa0', 'SPACE'), ('finishing', 'VERB'), ('\xa0', 'SPACE'), ('materials', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('offering', 'VERB'), ('\xa0', 'SPACE'), ('everything', 'PRON'), ('\xa0', 'SPACE'), ('you', 'PRON'), ('need', 'VERB'), ('\xa0', 'SPACE'), ('for', 'ADP'), ('\xa0', 'SPACE'), ('your', 'PRON'), ('\xa0', 'SPACE'), ('house', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('apartment', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('and', 'CCONJ'), ('\xa0', 'SPACE'), ('garden', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('including', 'VERB'), ('\xa0\n', 'SPACE'), ('supplies', 'NOUN'), ('\xa0', 'SPACE'), ('for', 'ADP'), ('\xa0', 'SPACE'), ('construction', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('restoration', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('finishing', 'NOUN'), (',', 'PUNCT'), ('\xa0', 'SPACE'), ('and', 'CCONJ'), ('\xa0', 'SPACE'), ('decoration', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Material', 'PROPN'), ('Transportation', 'PROPN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Material', 'PROPN'), ('Quotes', 'PROPN'), ('\n', 'SPACE'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2217', 'NUM'), ('-', 'SYM'), ('9400', 'NUM')]}),
#  Document(id=4d60b2dd40726b4afbb281826cb4ddb5f0a94843a3164d58f80d7aef11ffd7a3, content: 'Rent a Carrito, Golf Cart Rental, Golf Cart Repair, sales@rentacarrito.com, Monday - Friday 08:00 AM...', meta: {'pos_tags': [('Rent', 'VERB'), ('a', 'DET'), ('Carrito', 'PROPN'), (',', 'PUNCT'), ('Golf', 'PROPN'), ('Cart', 'PROPN'), ('Rental', 'PROPN'), (',', 'PUNCT'), ('Golf', 'PROPN'), ('Cart', 'PROPN'), ('Repair', 'PROPN'), (',', 'PUNCT'), ('sales@rentacarrito.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('08:00', 'NUM'), ('AM', 'NOUN'), ('–', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('08:00', 'NUM'), ('AM', 'PROPN'), ('–', 'PUNCT'), ('3:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Rent', 'PROPN'), ('a', 'DET'), ('Carrito', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('one', 'NUM'), ('-', 'PUNCT'), ('stop', 'NOUN'), ('shop', 'NOUN'), ('for', 'ADP'), ('renting', 'VERB'), ('golf', 'NOUN'), ('carts', 'NOUN'), (',', 'PUNCT'), ('bicycles', 'NOUN'), (',', 'PUNCT'), ('motorcycles', 'NOUN'), (',', 'PUNCT'), ('Navi', 'PROPN'), ('Scooters', 'PROPN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('more', 'ADJ'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('They', 'PRON'), ('offer', 'VERB'), ('rentals', 'NOUN'), ('on', 'ADP'), ('a', 'DET'), ('daily', 'ADJ'), (',', 'PUNCT'), ('weekly', 'ADJ'), (',', 'PUNCT'), ('and', 'CCONJ'), ('monthly', 'ADJ'), ('basis', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Additionally', 'ADV'), (',', 'PUNCT'), ('customers', 'NOUN'), ('have', 'VERB'), ('an', 'DET'), ('option', 'NOUN'), ('to', 'PART'), ('buy', 'VERB'), ('new', 'ADJ'), ('or', 'CCONJ'), ('used', 'ADJ'), ('golf', 'NOUN'), ('carts', 'NOUN'), ('from', 'ADP'), ('Rent', 'PROPN'), ('a', 'DET'), ('Carrito', 'PROPN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Repair', 'PROPN'), ('services', 'NOUN'), ('\n', 'SPACE'), ('•', 'NOUN'), ('A', 'DET'), ('store', 'NOUN'), ('of', 'ADP'), ('accessories', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Lithium', 'PROPN'), ('Electric', 'PROPN'), ('Golf', 'PROPN'), ('Carts', 'PROPN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Gas', 'PROPN'), ('Golf', 'PROPN'), ('Carts', 'PROPN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2670', 'NUM'), ('-', 'SYM'), ('0051', 'NUM')]}),
#  Document(id=92ad712551535fbea77853f5c4aee71f36fa3a486f678013b54123e0717b474d, content: 'Coco Market, Supermarket, no information available, Monday - Sunday 7:30 AM - 9:30 PM, Playa del Coc...', meta: {'pos_tags': [('Coco', 'PROPN'), ('Market', 'PROPN'), (',', 'PUNCT'), ('Supermarket', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('7:30', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('9:30', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Coco', 'PROPN'), ('Market', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('local', 'ADJ'), ('store', 'NOUN'), ('where', 'SCONJ'), ('you', 'PRON'), ('can', 'AUX'), ('find', 'VERB'), ('a', 'DET'), ('variety', 'NOUN'), ('of', 'ADP'), ('beverages', 'NOUN'), (',', 'PUNCT'), ('alcohol', 'PROPN'), (',', 'PUNCT'), ('snacks', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('cigarettes', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2670', 'NUM'), ('-', 'SYM'), ('0301', 'NUM')]}),
#  Document(id=dbc6dc62a8e802c474cf014a980a6ea4a4f4248e62e7df9dd112e86d9536410e, content: 'Eco Moda, Speciality & Gift Shops, no information available, Monday - Saturday 09:00 AM – 7:00 PM, S...', meta: {'pos_tags': [('Eco', 'PROPN'), ('Moda', 'PROPN'), (',', 'PUNCT'), ('Speciality', 'PROPN'), ('&', 'CCONJ'), ('Gift', 'PROPN'), ('Shops', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('09:00', 'NUM'), ('AM', 'NOUN'), ('–', 'PUNCT'), ('7:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Eco', 'PROPN'), ('Moda', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('second', 'ADJ'), ('-', 'PUNCT'), ('hand', 'NOUN'), ('clothing', 'NOUN'), ('store', 'NOUN'), ('for', 'ADP'), ('adults', 'NOUN'), ('and', 'CCONJ'), ('children', 'NOUN'), (',', 'PUNCT'), ('home', 'NOUN'), ('textiles', 'NOUN'), ('and', 'CCONJ'), ('gifts', 'NOUN'), ('.', 'PUNCT'), ('\xa0\n\n', 'SPACE'), ('•', 'NUM'), ('High', 'ADJ'), ('quality', 'NOUN'), ('American', 'ADJ'), ('brands', 'NOUN'), ('\n', 'SPACE'), ('•', 'VERB'), ('Always', 'ADV'), ('great', 'ADJ'), ('prices', 'NOUN'), (',', 'PUNCT'), ('+506', 'NOUN'), ('6430', 'NUM'), ('-', 'SYM'), ('4050', 'NUM')]}),
#  Document(id=f10c45285cf17611c76e30ae615895daa174215a1b2161a3f2e9748386d0ab2e, content: 'Charging station Coopeguanacaste, EV Charging Station, no information available, Monday- Sunday Open...', meta: {'pos_tags': [('Charging', 'VERB'), ('station', 'NOUN'), ('Coopeguanacaste', 'PROPN'), (',', 'PUNCT'), ('EV', 'PROPN'), ('Charging', 'PROPN'), ('Station', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday-', 'PROPN'), ('Sunday', 'PROPN'), ('Open', 'VERB'), ('24', 'NUM'), ('hours', 'NOUN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Electric', 'PROPN'), ('Mobile', 'PROPN'), ('Charging', 'PROPN'), ('station', 'NOUN'), ('available', 'ADJ'), ('24/7', 'PROPN'), ('.', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=8726e5db4abd510cc3f2d1619957b9c534f11f32e3bf29b2813d761162963857, content: 'Taller Electroman, Car Repair, chimicc1975@gmail.com, Monday – Friday 8:00 AM – 5:00 PM, Saturday 8:...', meta: {'pos_tags': [('Taller', 'PROPN'), ('Electroman', 'PROPN'), (',', 'PUNCT'), ('Car', 'PROPN'), ('Repair', 'PROPN'), (',', 'PUNCT'), ('chimicc1975@gmail.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('–', 'PUNCT'), ('Friday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('–', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('–', 'PUNCT'), ('12:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('-', 'PUNCT'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Car', 'NOUN'), ('service', 'NOUN'), ('provides', 'VERB'), ('high', 'ADJ'), ('-', 'PUNCT'), ('quality', 'NOUN'), ('car', 'NOUN'), ('repair', 'NOUN'), ('and', 'CCONJ'), ('maintenance', 'NOUN'), ('services', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Fuel', 'PROPN'), ('injectors', 'NOUN'), ('cleaning', 'VERB'), ('\n', 'SPACE'), ('•', 'NUM'), ('Reparation', 'NOUN'), ('of', 'ADP'), ('starter', 'NOUN'), ('and', 'CCONJ'), ('alternator', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Overhaul', 'PROPN'), ('and', 'CCONJ'), ('tuning', 'VERB'), ('\n', 'SPACE'), ('•', 'NUM'), ('Fast', 'ADJ'), ('mechanic', 'NOUN'), ('services', 'NOUN'), (',', 'PUNCT'), ('+506', 'NOUN'), ('8750', 'NUM'), ('-', 'SYM'), ('4075', 'NUM'), (' ', 'SPACE'), ('+506', 'PROPN'), ('8596', 'NUM'), ('-', 'PUNCT'), ('4407', 'NUM'), ('\n\n', 'SPACE')]}),
#  Document(id=48f288a625d34257607915560f33838a489176b04a9ce847e3896a409de043d7, content: 'Mayca, Supermarket, lbadonarvaez@mayca.com, Monday – Saturday 8:00 AM – 7:00 PM, Sunday 9:00 AM – 5:...', meta: {'pos_tags': [('Mayca', 'PROPN'), (',', 'PUNCT'), ('Supermarket', 'PROPN'), (',', 'PUNCT'), ('lbadonarvaez@mayca.com', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('–', 'PUNCT'), ('Saturday', 'PROPN'), ('8:00', 'NUM'), ('AM', 'NOUN'), ('–', 'PUNCT'), ('7:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('–', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Mayca', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('leader', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('sale', 'NOUN'), (',', 'PUNCT'), ('marketing', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('distribution', 'NOUN'), ('of', 'ADP'), ('food', 'NOUN'), ('and', 'CCONJ'), ('non', 'ADJ'), ('-', 'ADJ'), ('food', 'ADJ'), ('products', 'NOUN'), ('for', 'ADP'), ('professionals', 'NOUN'), (',', 'PUNCT'), ('including', 'VERB'), ('restaurants', 'NOUN'), (',', 'PUNCT'), ('hotels', 'NOUN'), (',', 'PUNCT'), ('pizzerias', 'NOUN'), (',', 'PUNCT'), ('bakeries', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('catering', 'NOUN'), ('services', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Food', 'PROPN'), ('Service', 'PROPN'), ('for', 'ADP'), ('HoReCa', 'SYM'), ('\n', 'SPACE'), ('•', 'X'), ('Chef', 'PROPN'), ("'s", 'PART'), ('Business', 'PROPN'), ('Resources', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
# ...
#  Document(id=fc0f5d9421fbd7c9e47f782a687adf0a610d490eae330c449498f843e11c4638, content: 'Banco de Costa Rica, Bank, ATM, no information available, Monday - Friday 9:00 AM - 3:30 PM, Saturda...', meta: {'pos_tags': [('Banco', 'PROPN'), ('de', 'PROPN'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), (',', 'PUNCT'), ('Bank', 'PROPN'), (',', 'PUNCT'), ('ATM', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('9:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('3:30', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('  ', 'SPACE'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Banco', 'PROPN'), ('de', 'PROPN'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), ('(', 'PUNCT'), ('BCR', 'PROPN'), (')', 'PUNCT'), ('is', 'AUX'), ('a', 'DET'), ('leading', 'VERB'), ('bank', 'NOUN'), ('in', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), (',', 'PUNCT'), ('offering', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('financial', 'ADJ'), ('services', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Branches', 'PROPN'), ('and', 'CCONJ'), ('ATMs', 'NOUN'), ('are', 'AUX'), ('conveniently', 'ADV'), ('located', 'VERB'), ('throughout', 'ADP'), ('the', 'DET'), ('country', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Provides', 'VERB'), ('a', 'DET'), ('ticket', 'NOUN'), ('system', 'NOUN'), ('for', 'ADP'), ('efficient', 'ADJ'), ('service', 'NOUN'), ('\n', 'SPACE'), ('•', 'NOUN'), ('A', 'DET'), ('separate', 'ADJ'), ('queue', 'NOUN'), ('for', 'ADP'), ('elderly', 'ADJ'), ('customers', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Payments', 'NOUN'), ('and', 'CCONJ'), ('transfers', 'NOUN'), ('made', 'VERB'), ('at', 'ADP'), ('cashier', 'NOUN'), ('\n', 'SPACE'), ('•', 'VERB'), ('Opening', 'NOUN'), ('an', 'DET'), ('account', 'NOUN'), ('requires', 'VERB'), ('help', 'NOUN'), ('at', 'ADP'), ('service', 'NOUN'), ('platform', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2211', 'NUM'), ('-', 'SYM'), ('1111', 'NUM')]}),
#  Document(id=4b5c07cc09ed666a0bb58106ed2073d7bb2c450f36e3c520ee0ff9539fc12f00, content: 'Banco Nacional, Bank, ATM, no information available, Monday - Friday 8:30 AM - 3:30 PM, Saturday - S...', meta: {'pos_tags': [('Banco', 'PROPN'), ('Nacional', 'PROPN'), (',', 'PUNCT'), ('Bank', 'PROPN'), (',', 'PUNCT'), ('ATM', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Friday', 'PROPN'), ('8:30', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('3:30', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('Saturday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('closed', 'VERB'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Banco', 'PROPN'), ('Nacional', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('leading', 'VERB'), ('financial', 'ADJ'), ('institution', 'NOUN'), ('in', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), (',', 'PUNCT'), ('known', 'VERB'), ('for', 'ADP'), ('its', 'PRON'), ('reliable', 'ADJ'), ('and', 'CCONJ'), ('customer', 'NOUN'), ('-', 'PUNCT'), ('centric', 'ADJ'), ('services', 'NOUN'), ('and', 'CCONJ'), ('branches', 'NOUN'), ('across', 'ADP'), ('the', 'DET'), ('country', 'NOUN'), ('.', 'PUNCT'), ('              \n\n', 'SPACE'), ('•', 'X'), ('Mobile', 'PROPN'), ('app', 'NOUN'), ('and', 'CCONJ'), ('online', 'ADJ'), ('banking', 'NOUN'), ('\n', 'SPACE'), ('•', 'X'), ('Solutions', 'NOUN'), ('to', 'ADP'), ('individuals', 'NOUN'), ('and', 'CCONJ'), ('businesses', 'NOUN'), ('alike', 'ADV'), ('\n', 'SPACE'), ('•', 'NOUN'), ('A', 'DET'), ('full', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('banking', 'NOUN'), ('services', 'NOUN'), (',', 'PUNCT'), (' ', 'SPACE'), ('+506', 'PROPN'), ('2670', 'NUM'), ('-', 'SYM'), ('0644', 'NUM')]}),
#  Document(id=ef405a86e3c5577670f9127f4d8c1424b99757fce30750cd37346a0be2b3a0eb, content: 'Coopeguanacaste, Utilities, servicioalcliente@coopeguanacaste.com, Monday - Saturday 7:00 AM - 5:00 ...', meta: {'pos_tags': [('Coopeguanacaste', 'PROPN'), (',', 'PUNCT'), ('Utilities', 'PROPN'), (',', 'PUNCT'), ('servicioalcliente@coopeguanacaste.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('7:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('5:00', 'NUM'), ('PM', 'NOUN'), (',', 'PUNCT'), ('\n', 'SPACE'), ('Sunday', 'PROPN'), (' ', 'SPACE'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Coopeguanacaste', 'PROPN'), ('R.L.', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('cooperative', 'NOUN'), ('in', 'ADP'), ('Guanacaste', 'PROPN'), ('Province', 'PROPN'), ('that', 'PRON'), ('distributes', 'VERB'), ('energy', 'NOUN'), ('to', 'ADP'), ('homes', 'NOUN'), (',', 'PUNCT'), ('companies', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('industries', 'NOUN'), ('around', 'ADP'), ('the', 'DET'), ('Nicoya', 'PROPN'), ('Peninsula', 'PROPN'), ('.', 'PUNCT'), ('\xa0\n\n', 'SPACE'), ('In', 'ADP'), ('addition', 'NOUN'), ('to', 'ADP'), ('energy', 'NOUN'), ('services', 'NOUN'), (',', 'PUNCT'), ('it', 'PRON'), ('provides', 'VERB'), ('other', 'ADJ'), ('products', 'NOUN'), ('and', 'CCONJ'), ('services', 'NOUN'), (',', 'PUNCT'), ('such', 'ADJ'), ('as', 'ADP'), ('white', 'ADJ'), ('goods', 'NOUN'), (',', 'PUNCT'), ('electrical', 'ADJ'), ('supplies', 'NOUN'), (',', 'PUNCT'), ('insurance', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('telecommunications', 'NOUN'), ('services', 'NOUN'), ('like', 'ADP'), ('Internet', 'NOUN'), (',', 'PUNCT'), ('digital', 'ADJ'), ('television', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('IP', 'PROPN'), ('telephone', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Billing', 'PROPN'), ('and', 'CCONJ'), ('Payments', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Household', 'PROPN'), ('appliances', 'NOUN'), (',', 'PUNCT'), ('power', 'NOUN'), ('tools', 'NOUN'), (',', 'PUNCT'), ('\xa0 ', 'SPACE'), ('electrical', 'ADJ'), ('supplies', 'NOUN'), ('\n', 'SPACE'), ('•', 'X'), ('Internet', 'NOUN'), (',', 'PUNCT'), ('Television', 'PROPN'), (',', 'PUNCT'), ('IP', 'PROPN'), ('Telephony', 'PROPN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Distribution', 'NOUN'), ('of', 'ADP'), ('clean', 'ADJ'), ('energy', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2681', 'NUM'), ('-', 'SYM'), ('4700', 'NUM')]}),
#  Document(id=25dad1f7eae8a6f877c615c2c11b99bfa35a554eb5926b23f768ba52d373a16e, content: 'Liberia International Airport, Airport,
#  info@guanacasteairport.com, Monday - Sunday 6:00 AM - 12:00...', meta: {'pos_tags': [('Liberia', 'PROPN'), ('International', 'PROPN'), ('Airport', 'PROPN'), (',', 'PUNCT'), ('Airport', 'PROPN'), (',', 'PUNCT'), ('\n', 'SPACE'), ('info@guanacasteairport.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('6:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('12:00', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Daniel', 'PROPN'), ('Oduber', 'PROPN'), ('Quirós', 'PROPN'), ('International', 'PROPN'), ('Airport', 'PROPN'), ('(', 'PUNCT'), ('LIR', 'PROPN'), (')', 'PUNCT'), (',', 'PUNCT'), ('located', 'VERB'), ('just', 'ADV'), ('outside', 'ADP'), ('Liberia', 'PROPN'), (',', 'PUNCT'), ('Guanacaste', 'PROPN'), (',', 'PUNCT'), ('is', 'AUX'), ('a', 'DET'), ('major', 'ADJ'), ('gateway', 'NOUN'), ('to', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), ("'s", 'PART'), ('Pacific', 'PROPN'), ('coast', 'NOUN'), ('.', 'PUNCT'), ('\xa0\n\n', 'SPACE'), ('The', 'DET'), ('airport', 'NOUN'), ('features', 'VERB'), ('a', 'DET'), ('small', 'ADJ'), ('shop', 'NOUN'), ('with', 'ADP'), ('snacks', 'NOUN'), (',', 'PUNCT'), ('drinks', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('ready', 'ADJ'), ('-', 'PUNCT'), ('to', 'PART'), ('-', 'PUNCT'), ('eat', 'VERB'), ('food', 'NOUN'), (',', 'PUNCT'), ('as', 'ADV'), ('well', 'ADV'), ('as', 'ADP'), ('two', 'NUM'), ('small', 'ADJ'), ('restaurants', 'NOUN'), ('inside', 'ADV'), ('.', 'PUNCT'), ('\xa0\n', 'SPACE'), ('Parking', 'NOUN'), ('is', 'AUX'), ('available', 'ADJ'), ('for', 'ADP'), ('cars', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('although', 'SCONJ'), ('it', 'PRON'), ('is', 'AUX'), ('currently', 'ADV'), ('free', 'ADJ'), (',', 'PUNCT'), ('a', 'DET'), ('paid', 'VERB'), ('parking', 'NOUN'), ('system', 'NOUN'), ('will', 'AUX'), ('soon', 'ADV'), ('be', 'AUX'), ('introduced', 'VERB'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Private', 'ADJ'), ('cars', 'NOUN'), ('must', 'AUX'), ('park', 'VERB'), ('further', 'ADV'), ('from', 'ADP'), ('the', 'DET'), ('airport', 'NOUN'), (',', 'PUNCT'), ('with', 'ADP'), ('only', 'ADJ'), ('rental', 'ADJ'), ('cars', 'NOUN'), ('and', 'CCONJ'), ('official', 'ADJ'), ('tour', 'NOUN'), ('buses', 'NOUN'), ('allowed', 'VERB'), ('to', 'PART'), ('park', 'VERB'), ('closer', 'ADV'), ('.', 'PUNCT'), ('\xa0\n', 'SPACE'), ('Quick', 'PROPN'), ('drop', 'NOUN'), ('-', 'PUNCT'), ('off', 'NOUN'), ('and', 'CCONJ'), ('pick', 'VERB'), ('-', 'PUNCT'), ('up', 'NOUN'), ('at', 'ADP'), ('the', 'DET'), ('airport', 'NOUN'), ('entrance', 'NOUN'), ('are', 'AUX'), ('required', 'VERB'), (',', 'PUNCT'), ('as', 'SCONJ'), ('lingering', 'VERB'), ('is', 'AUX'), ('not', 'PART'), ('permitted', 'VERB'), ('.', 'PUNCT'), ('The', 'DET'), ('airport', 'NOUN'), ('has', 'VERB'), ('good', 'ADJ'), ('restrooms', 'NOUN'), ('and', 'CCONJ'), ('convenient', 'ADJ'), ('facilities', 'NOUN'), ('for', 'ADP'), ('passengers', 'NOUN'), ('.', 'PUNCT'), ('\xa0\n\n', 'SPACE'), ('•', 'NUM'), ('Taxi', 'PROPN'), ('drivers', 'NOUN'), ('at', 'ADP'), ('the', 'DET'), ('departure', 'NOUN'), ('\xa0\n', 'SPACE'), ('•', 'NOUN'), ('Transfers', 'PROPN'), ('booked', 'VERB'), ('in', 'ADP'), ('advance', 'NOUN'), ('are', 'AUX'), ('advised', 'VERB'), (',', 'PUNCT'), ('+506', 'NOUN'), ('2666', 'NUM'), ('-', 'SYM'), ('9600', 'NUM')]}),
#  Document(id=57ee818c65e2bbdba709a0771f80a59fd23a21683a931a518760f229bb545a05, content: 'Playa del Coco, Beaches, no information available, no information available, Playa del Coco, Playas ...', meta: {'pos_tags': [('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Beaches', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Playas', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), ('is', 'AUX'), ('a', 'DET'), ('vibrant', 'ADJ'), ('hub', 'NOUN'), ('of', 'ADP'), ('activity', 'NOUN'), (',', 'PUNCT'), ('offering', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('water', 'NOUN'), ('sports', 'NOUN'), (',', 'PUNCT'), ('diving', 'NOUN'), (',', 'PUNCT'), ('fishing', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('lively', 'ADJ'), ('nightlife', 'NOUN'), ('.', 'PUNCT'), ('Known', 'VERB'), ('affectionately', 'ADV'), ('as', 'ADP'), ('“', 'PUNCT'), ('El', 'PROPN'), ('Coco', 'PROPN'), ('”', 'PUNCT'), ('by', 'ADP'), ('locals', 'NOUN'), (',', 'PUNCT'), ('this', 'DET'), ('area', 'NOUN'), ('buzzes', 'VERB'), ('with', 'ADP'), ('excitement', 'NOUN'), ('from', 'ADP'), ('sunrise', 'NOUN'), ('to', 'ADP'), ('sunset', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('If', 'SCONJ'), ('you', 'PRON'), ("'re", 'AUX'), ('looking', 'VERB'), ('for', 'ADP'), ('a', 'DET'), ('beach', 'NOUN'), ('vacation', 'NOUN'), ('in', 'ADP'), ('one', 'NUM'), ('of', 'ADP'), ('Costa', 'PROPN'), ('Rica', 'PROPN'), ("'s", 'PART'), ('most', 'ADV'), ('popular', 'ADJ'), ('expat', 'NOUN'), ('destinations', 'NOUN'), (',', 'PUNCT'), ('Playas', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), ('is', 'AUX'), ('the', 'DET'), ('place', 'NOUN'), ('to', 'PART'), ('be', 'AUX'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'NUM'), ('Light', 'ADJ'), ('sand', 'NOUN'), ('with', 'ADP'), ('some', 'DET'), ('pebbles', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Wide', 'ADJ'), ('and', 'CCONJ'), ('long', 'ADJ'), ('beach', 'NOUN'), (',', 'PUNCT'), ('suitable', 'ADJ'), ('for', 'ADP'), ('various', 'ADJ'), ('activities', 'NOUN'), ('\n', 'SPACE'), ('•', 'X'), ('Activities', 'NOUN'), (':', 'PUNCT'), ('Water', 'NOUN'), ('sports', 'NOUN'), (',', 'PUNCT'), ('diving', 'NOUN'), (',', 'PUNCT'), ('fishing', 'NOUN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ')]}),
#  Document(id=6a386e616483568f43b8dc5a3976012ddb9321caf50ab583a08d548cca507638, content: 'Mega Super, Supermarket, no information available, Monday - Saturday 7:00 AM - 10:00 PM Sunday 7:00 ...', meta: {'pos_tags': [('Mega', 'PROPN'), ('Super', 'PROPN'), (',', 'PUNCT'), ('Supermarket', 'PROPN'), (',', 'PUNCT'), ('no', 'DET'), ('information', 'NOUN'), ('available', 'ADJ'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('7:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('10:00', 'NUM'), ('PM', 'NOUN'), ('Sunday', 'PROPN'), ('7:00', 'NUM'), ('AM', 'NOUN'), ('-', 'PUNCT'), ('9:00', 'NUM'), ('PM', 'NOUN'), ('\n\n', 'SPACE'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('Mega', 'PROPN'), ('Super', 'PROPN'), ('offers', 'VERB'), ('a', 'DET'), ('wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('products', 'NOUN'), (',', 'PUNCT'), ('from', 'ADP'), ('fresh', 'ADJ'), ('groceries', 'NOUN'), ('and', 'CCONJ'), ('beverages', 'NOUN'), ('to', 'ADP'), ('cleaning', 'VERB'), ('supplies', 'NOUN'), ('and', 'CCONJ'), ('household', 'NOUN'), ('chemicals', 'NOUN'), (',', 'PUNCT'), ('catering', 'VERB'), ('to', 'ADP'), ('all', 'DET'), ('your', 'PRON'), ('needs', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Discounts', 'NOUN'), ('and', 'CCONJ'), ('special', 'ADJ'), ('promotions', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Friendly', 'ADJ'), ('staff', 'NOUN'), ('and', 'CCONJ'), ('high', 'ADJ'), ('-', 'PUNCT'), ('quality', 'NOUN'), ('products', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Wide', 'ADJ'), ('range', 'NOUN'), ('of', 'ADP'), ('products', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Utility', 'PROPN'), ('bill', 'NOUN'), ('payment', 'NOUN'), ('services', 'NOUN'), ('\n', 'SPACE'), (',', 'PUNCT'), ('+506', 'PROPN'), ('2670', 'NUM'), ('-', 'SYM'), ('1239', 'NUM')]}),
#  Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]})]

# %%
model = "sentence-transformers/multi-qa-mpnet-base-dot-v1"

document_store = InMemoryDocumentStore()

indexing_pipeline = Pipeline()

indexing_pipeline.add_component(instance=SentenceTransformersDocumentEmbedder(model=model), name="embedder")
indexing_pipeline.add_component(instance=DocumentWriter(document_store=document_store), name="writer")
indexing_pipeline.connect("embedder.documents", "writer.documents")

indexing_pipeline.run({"documents": documents})


retriever = InMemoryEmbeddingRetriever(document_store=document_store)
reader = ExtractiveReader()
reader.warm_up()
# Out:
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# Создаем пайплайн для извлечения ответов
extractive_qa_pipeline = Pipeline()

# %%
# Добавляем новый компонент для использования POS-tagging
class PosTaggingReader(ExtractiveReader):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def extract_answers(self, query, documents):
        answers = []
        for doc in documents:
            pos_tags = doc.meta['pos_tags']
            for token, pos in pos_tags:
                if pos == 'NN' and token in query:
                    answers.append(token)
        return answers

pos_tagging_reader = PosTaggingReader()

# Добавляем компоненты в пайплайн
extractive_qa_pipeline.add_component(instance=SentenceTransformersTextEmbedder(model=model), name="embedder")
extractive_qa_pipeline.add_component(instance=retriever, name="retriever")
extractive_qa_pipeline.add_component(instance=pos_tagging_reader, name="reader")

# Соединяем компоненты в пайплайн
extractive_qa_pipeline.connect("embedder.embedding", "retriever.query_embedding")
extractive_qa_pipeline.connect("retriever.documents", "reader.documents")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7e724e502530>
# 🚅 Components
#   - embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
#   - reader: PosTaggingReader
# 🛤️ Connections
#   - embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> reader.documents (List[Document])

# %%
query = "What are the opening hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.843254804611206, data='11:00 AM - 2:30 AM', document=Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]}, score: 26.02480504900634), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8176265358924866, data='Monday - Sunday', document=Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]}, score: 26.02480504900634), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8102079033851624, data='4:00 PM - 12:00 AM', document=Document(id=3c4bb84f36f964963ac999918c29d8390311a3713a8a742cff9b7ae48a81fe5e, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', meta: {'pos_tags': [('Zarpe', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('LASENORA@ZARPE.BAR', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('4:00', 'NUM'), ('PM', 'NOUN'), ('-', 'PUNCT'), ('12:00', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('-', 'PUNCT'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('The', 'DET'), ('lively', 'ADJ'), ('atmosphere', 'NOUN'), ('features', 'VERB'), ('live', 'ADJ'), ('music', 'NOUN'), (',', 'PUNCT'), ('a', 'DET'), ('wide', 'ADJ'), ('drink', 'NOUN'), ('selection', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('a', 'DET'), ('cocktail', 'NOUN'), ('lounge', 'NOUN'), ('for', 'ADP'), ('special', 'ADJ'), ('experiences', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('establishment', 'NOUN'), ('also', 'ADV'), ('provides', 'VERB'), ('dance', 'NOUN'), ('classes', 'NOUN'), (',', 'PUNCT'), ('yoga', 'NOUN'), (',', 'PUNCT'), ('live', 'ADJ'), ('music', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('evenings', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('much', 'ADV'), ('more', 'ADJ'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Bar', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Live', 'ADJ'), ('music', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('DJs', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Premium', 'PROPN'), ('cocktail', 'NOUN'), ('lounge', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('6488', 'NUM'), ('-', 'SYM'), ('6622', 'NUM')]}, score: 21.360876198648455), context=None, document_offset=ExtractedAnswer.Span(start=70, end=88), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.005425428050080489, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "What are the opening days and hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8397794961929321, data='Monday - Sunday', document=Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]}, score: 26.470380126861734), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8241560459136963, data='Monday - Saturday', document=Document(id=3c4bb84f36f964963ac999918c29d8390311a3713a8a742cff9b7ae48a81fe5e, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', meta: {'pos_tags': [('Zarpe', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('LASENORA@ZARPE.BAR', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('4:00', 'NUM'), ('PM', 'NOUN'), ('-', 'PUNCT'), ('12:00', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('-', 'PUNCT'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('The', 'DET'), ('lively', 'ADJ'), ('atmosphere', 'NOUN'), ('features', 'VERB'), ('live', 'ADJ'), ('music', 'NOUN'), (',', 'PUNCT'), ('a', 'DET'), ('wide', 'ADJ'), ('drink', 'NOUN'), ('selection', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('a', 'DET'), ('cocktail', 'NOUN'), ('lounge', 'NOUN'), ('for', 'ADP'), ('special', 'ADJ'), ('experiences', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('establishment', 'NOUN'), ('also', 'ADV'), ('provides', 'VERB'), ('dance', 'NOUN'), ('classes', 'NOUN'), (',', 'PUNCT'), ('yoga', 'NOUN'), (',', 'PUNCT'), ('live', 'ADJ'), ('music', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('evenings', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('much', 'ADV'), ('more', 'ADJ'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Bar', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Live', 'ADJ'), ('music', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('DJs', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Premium', 'PROPN'), ('cocktail', 'NOUN'), ('lounge', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('6488', 'NUM'), ('-', 'SYM'), ('6622', 'NUM')]}, score: 21.329905508721964), context=None, document_offset=ExtractedAnswer.Span(start=52, end=69), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.791502058506012, data='11:00 AM - 2:30 AM', document=Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]}, score: 26.470380126861734), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.005874180745854627, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "When is open the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.786523699760437, data='Monday - Sunday', document=Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]}, score: 27.195980742193726), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.7416019439697266, data='Monday - Saturday', document=Document(id=3c4bb84f36f964963ac999918c29d8390311a3713a8a742cff9b7ae48a81fe5e, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', meta: {'pos_tags': [('Zarpe', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('LASENORA@ZARPE.BAR', 'PROPN'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Saturday', 'PROPN'), ('4:00', 'NUM'), ('PM', 'NOUN'), ('-', 'PUNCT'), ('12:00', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Sunday', 'PROPN'), ('-', 'PUNCT'), ('Closed', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('The', 'DET'), ('lively', 'ADJ'), ('atmosphere', 'NOUN'), ('features', 'VERB'), ('live', 'ADJ'), ('music', 'NOUN'), (',', 'PUNCT'), ('a', 'DET'), ('wide', 'ADJ'), ('drink', 'NOUN'), ('selection', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('a', 'DET'), ('cocktail', 'NOUN'), ('lounge', 'NOUN'), ('for', 'ADP'), ('special', 'ADJ'), ('experiences', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('The', 'DET'), ('establishment', 'NOUN'), ('also', 'ADV'), ('provides', 'VERB'), ('dance', 'NOUN'), ('classes', 'NOUN'), (',', 'PUNCT'), ('yoga', 'NOUN'), (',', 'PUNCT'), ('live', 'ADJ'), ('music', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('evenings', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('much', 'ADV'), ('more', 'ADJ'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('•', 'X'), ('Bar', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Live', 'ADJ'), ('music', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('DJs', 'NOUN'), ('\n', 'SPACE'), ('•', 'NUM'), ('Premium', 'PROPN'), ('cocktail', 'NOUN'), ('lounge', 'NOUN'), (',', 'PUNCT'), ('+506', 'PROPN'), ('6488', 'NUM'), ('-', 'SYM'), ('6622', 'NUM')]}, score: 21.518277971272383), context=None, document_offset=ExtractedAnswer.Span(start=52, end=69), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.6876878142356873, data='11:00 AM - 2:30 AM', document=Document(id=cd115b04dbac72c7c7b41f1d8310fa2ec93bb3fb2704c6d18a3829da87338b58, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', meta: {'pos_tags': [('Zi', 'PROPN'), ('Lounge', 'PROPN'), (',', 'PUNCT'), ('Restaurant', 'PROPN'), (',', 'PUNCT'), ('Bar', 'PROPN'), (',', 'PUNCT'), ('International', 'PROPN'), (',', 'PUNCT'), ('Seafood', 'PROPN'), (',', 'PUNCT'), ('Pizza', 'PROPN'), (',', 'PUNCT'), ('Pasta', 'PROPN'), (',', 'PUNCT'), ('Meat', 'NOUN'), (',', 'PUNCT'), ('Steak', 'PROPN'), (',', 'PUNCT'), ('Salads', 'PROPN'), (',', 'PUNCT'), ('Cocktails', 'PROPN'), (',', 'PUNCT'), ('Alcohol', 'PROPN'), (',', 'PUNCT'), ('info@zilounge.com', 'X'), (',', 'PUNCT'), ('Monday', 'PROPN'), ('-', 'PUNCT'), ('Sunday', 'PROPN'), ('11:00', 'NUM'), ('AM', 'PROPN'), ('-', 'PUNCT'), ('2:30', 'NUM'), ('AM', 'PROPN'), (',', 'PUNCT'), ('Playa', 'PROPN'), ('del', 'PROPN'), ('Coco', 'PROPN'), (',', 'PUNCT'), ('In', 'ADP'), ('this', 'DET'), ('bar', 'NOUN'), ('-', 'PUNCT'), ('restaurant', 'NOUN'), (',', 'PUNCT'), ('there', 'PRON'), ('are', 'VERB'), ('dishes', 'NOUN'), ('and', 'CCONJ'), ('drinks', 'NOUN'), ('for', 'ADP'), ('every', 'DET'), ('taste', 'NOUN'), ('and', 'CCONJ'), ('at', 'ADP'), ('any', 'DET'), ('convenient', 'ADJ'), ('time', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Parties', 'NOUN'), ('and', 'CCONJ'), ('theme', 'NOUN'), ('nights', 'NOUN'), ('are', 'AUX'), ('also', 'ADV'), ('organized', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('restaurant', 'NOUN'), ('.', 'PUNCT'), (',', 'PUNCT'), ('+506', 'PROPN'), ('8888', 'NUM'), ('-', 'SYM'), ('3939', 'NUM')]}, score: 27.195980742193726), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.017227721376750892, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %% [markdown]
# Использование Part-of-speech tagging (POS-tagging) не оправдало ожидание.

# %% [markdown]
# Попробуем использовать Named Entity Recognition (NER).
#
# Named Entity Recognition (NER) — это задача в области обработки естественного языка (NLP), которая заключается в идентификации и классификации именованных сущностей в тексте. Именованными сущностями могут быть имена собственные, такие как имена людей, названия организаций, географические названия, даты, временные интервалы, денежные суммы и другие специфические категории, которые имеют конкретное значение в контексте.
#
# Основные аспекты NER:
#
# 1. **Идентификация**: Процесс выделения последовательностей символов, которые представляют собой именованные сущности. Например, в предложении "Илон Маск основал SpaceX в 2002 году" NER-система должна идентифицировать "Илон Маск", "SpaceX" и "2002" как потенциальные именованные сущности.
#
# 2. **Классификация**: После идентификации система классифицирует каждую сущность в одну из предопределённых категорий. В приведённом примере "Илон Маск" может быть классифицирован как "PERSON" (человек), "SpaceX" как "ORGANIZATION" (организация), а "2002" как "DATE" (дата).
#
# 3. **Контекстуальный анализ**: NER-системы должны учитывать контекст, поскольку некоторые слова и фразы могут быть омонимами или иметь разные значения в зависимости от окружения. Например, "Apple" может означать как технологическую компанию, так и фрукт.
#
# NER используется в различных приложениях, таких как извлечение информации, автоматическое аннотирование текстов, улучшение поиска по ключевым словам и анализ текстовых данных в реальном времени. Современные системы NER часто строятся с использованием машинного обучения и глубокого обучения, что позволяет им достигать высокой точности в сложных и многозначных текстах.

# %% [markdown]
# Следует отметить, что en_core_web_sm базовая модель в spacy. В нашем случае используется и в POS-tagging и NER. Бывают сложнее.

# %%
retriever = InMemoryEmbeddingRetriever(document_store=document_store)

# %%
# Создаем пайплайн для извлечения ответов
extractive_qa_pipeline = Pipeline()

# %%
class NERReader(ExtractiveReader):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def extract_answers(self, query, documents):
        answers = []
        for doc in documents:
            text = doc.content
            doc_spacy = nlp(text)
            for ent in doc_spacy.ents:
                if ent.text in query:
                    answers.append(ent.text)
        return answers

# %%
ner_reader = NERReader()

# Добавляем компонент в пайплайн
extractive_qa_pipeline.add_component(instance=ner_reader, name="reader")
extractive_qa_pipeline.add_component(instance=SentenceTransformersTextEmbedder(model=model), name="embedder")
extractive_qa_pipeline.add_component(instance=retriever, name="retriever")

# Соединяем компоненты в пайплайн
extractive_qa_pipeline.connect("embedder.embedding", "retriever.query_embedding")
extractive_qa_pipeline.connect("retriever.documents", "reader.documents")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7b6380613430>
# 🚅 Components
#   - reader: NERReader
#   - embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
# 🛤️ Connections
#   - embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> reader.documents (List[Document])

# %%
query = "What are the opening hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.843254804611206, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.02480504900634), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8176265358924866, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.02480504900634), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8102079033851624, data='4:00 PM - 12:00 AM', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 21.360876198648455), context=None, document_offset=ExtractedAnswer.Span(start=70, end=88), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.005425428050080489, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "What are the opening days and hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8397794961929321, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.470380126861734), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8241560459136963, data='Monday - Saturday', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 21.329905508721964), context=None, document_offset=ExtractedAnswer.Span(start=52, end=69), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.791502058506012, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.470380126861734), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.005874180745854627, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "When is open the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.786523699760437, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 27.195980742193726), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.7416019439697266, data='Monday - Saturday', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 21.518277971272383), context=None, document_offset=ExtractedAnswer.Span(start=52, end=69), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.6876878142356873, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 27.195980742193726), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.017227721376750892, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %% [markdown]
# Применение NER также не оправдало ожиданий. Можно конечно упороться в поиск навороченных spacy моделей, но мне кажется, в нашем случае нужно использовать другие подходы.

# %% [markdown]
# Попробуем Dependency Parsing - это способ анализа синтаксической структуры предложения, который позволяет нам определить зависимости между словами в предложении.

# %% [markdown]
# Попробуем собрать гибрид из того, о чем говорили ранее. Ретривер + Deberta в качестве Reader.

# %%
retriever = InMemoryEmbeddingRetriever(document_store=document_store)

# %%
# Создаем пайплайн для извлечения ответов
extractive_qa_pipeline = Pipeline()

# %%
class DependencyParsingReader(ExtractiveReader):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def extract_answers(self, query, documents):
        answers = []
        for doc in documents:
            text = doc.content
            doc_spacy = nlp(text)
            for token in doc_spacy:
                if token.dep_ == "ROOT":
                    root_token = token
                    for child in root_token.children:
                        if child.dep_ == "nsubj":
                            subject_token = child
                            answers.append(subject_token.text)
        return answers

# %%
dependency_parsing_reader = DependencyParsingReader()

# Добавляем компонент в пайплайн
extractive_qa_pipeline.add_component(instance=dependency_parsing_reader, name="reader")
extractive_qa_pipeline.add_component(instance=SentenceTransformersTextEmbedder(model=model), name="embedder")
extractive_qa_pipeline.add_component(instance=retriever, name="retriever")

# Соединяем компоненты в пайплайн
extractive_qa_pipeline.connect("embedder.embedding", "retriever.query_embedding")
extractive_qa_pipeline.connect("retriever.documents", "reader.documents")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7b63800e6fe0>
# 🚅 Components
#   - reader: DependencyParsingReader
#   - embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
# 🛤️ Connections
#   - embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> reader.documents (List[Document])

# %%
query = "What are the opening hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.843254804611206, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.02480504900634), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8176265358924866, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.02480504900634), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8102079033851624, data='4:00 PM - 12:00 AM', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 21.360876198648455), context=None, document_offset=ExtractedAnswer.Span(start=70, end=88), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.005425428050080489, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "What are the opening days and hours of the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8397794961929321, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.470380126861734), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8241560459136963, data='Monday - Saturday', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 21.329905508721964), context=None, document_offset=ExtractedAnswer.Span(start=52, end=69), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.791502058506012, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 26.470380126861734), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.005874180745854627, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "When is open the restaurant Zi Lounge?"
extractive_qa_pipeline.run(
    data={"embedder": {"text": query}, "retriever": {"top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'reader': {'answers': [ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.786523699760437, data='Monday - Sunday', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 27.195980742193726), context=None, document_offset=ExtractedAnswer.Span(start=126, end=141), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.7416019439697266, data='Monday - Saturday', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 21.518277971272383), context=None, document_offset=ExtractedAnswer.Span(start=52, end=69), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.6876878142356873, data='11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 27.195980742193726), context=None, document_offset=ExtractedAnswer.Span(start=142, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.017227721376750892, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %% [markdown]
# Dependency Parsing также не оправдал ожиданий.

# %% [markdown]
# Мы также можем попробовать использовать более сложные алгоритмы извлечения ответов, такие как Span-based QA или Sequence-to-sequence QA.

# %% [markdown]
# Смысла использовать Span-based QA нет, так как алгоритм хорошо работает, только если в тексте ответ напрямую присутствует в тексте.

# %%
# pip install farm-haystack

# %%
# from haystack.nodes import T5Reader
# from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
from haystack.components.retrievers.in_memory import InMemoryBM25Retriever

# %%
# Создаем DocumentStore
document_store = InMemoryDocumentStore()

# Добавляем документы в DocumentStore
document_store.write_documents(documents)

# Создаем InMemoryEmbeddingRetriever
retriever = InMemoryEmbeddingRetriever(document_store=document_store)

# %%
qa_pipeline = Pipeline()

# %%
retriever = InMemoryBM25Retriever(document_store=document_store)
qa_pipeline.add_component(instance=retriever, name="retriever")

# %%
qa_pipeline.add_component(instance=ExtractiveReader(model="deepset/deberta-v3-base-squad2"), name="reader")

# %%
# qa_pipeline.add_component(instance=InMemoryBM25Retriever(document_store=document_store), name="retriever")
# qa_pipeline.add_component(instance=ExtractiveReader(model="deepset/deberta-v3-base-squad2"), name="reader")

# %%
qa_pipeline.connect("retriever", "reader")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x780b17860640>
# 🚅 Components
#   - retriever: InMemoryBM25Retriever
#   - reader: ExtractiveReader
# 🛤️ Connections
#   - retriever.documents -> reader.documents (List[Document])

# %%
query = "What are the opening hours of the restaurant Zi Lounge?"
qa_pipeline.run(
    data={"retriever": {"query": query, "top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.8549867868423462, data=' Monday - Sunday 11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 25.75866793740871), context=None, document_offset=ExtractedAnswer.Span(start=125, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.6113113164901733, data=' Monday - Saturday 4:00 PM - 12:00 AM, Sunday - Closed', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 20.38204179149279), context=None, document_offset=ExtractedAnswer.Span(start=51, end=105), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.41231438517570496, data=' Monday-Sunday 8:00 AM–5:00 PM', document=Document(id=8b81474f0e6afc29e9e8a561b5408bc8032bdb274738538542cb52443b3c5599, content: 'Ricky Tour's (, Horseback Riding Tours, Nature & Wildlife Tours, no information available, Monday-Su...', score: 20.309957669392418), context=None, document_offset=ExtractedAnswer.Span(start=90, end=120), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening hours of the restaurant Zi Lounge?', score=0.03312489669047208, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "What are the opening days and hours of the restaurant Zi Lounge?"
qa_pipeline.run(
    data={"retriever": {"query": query, "top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# {'reader': {'answers': [ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.8552565574645996, data=' Monday - Sunday 11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 25.88915923886433), context=None, document_offset=ExtractedAnswer.Span(start=125, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.6460022926330566, data=' Monday - Saturday 4:00 PM - 12:00 AM, Sunday - Closed', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 20.497650393518462), context=None, document_offset=ExtractedAnswer.Span(start=51, end=105), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.4867812693119049, data=' Monday-Sunday 8:00 AM–5:00 PM', document=Document(id=8b81474f0e6afc29e9e8a561b5408bc8032bdb274738538542cb52443b3c5599, content: 'Ricky Tour's (, Horseback Riding Tours, Nature & Wildlife Tours, no information available, Monday-Su...', score: 20.44337365679895), context=None, document_offset=ExtractedAnswer.Span(start=90, end=120), context_offset=None, meta={}),
#    ExtractedAnswer(query='What are the opening days and hours of the restaurant Zi Lounge?', score=0.026296735923767234, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}

# %%
query = "When is open the restaurant Zi Lounge?"
qa_pipeline.run(
    data={"retriever": {"query": query, "top_k": 3}, "reader": {"query": query, "top_k": 3}}
)
# Out:
# {'reader': {'answers': [ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.757442057132721, data=' Monday - Sunday 11:00 AM - 2:30 AM', document=Document(id=e8a323a4533b246c32c4f3b40c1c583c7684cad1b757abb5e4bd8b211c473ac4, content: 'Zi Lounge, Restaurant, Bar, International, Seafood, Pizza, Pasta, Meat, Steak, Salads, Cocktails, Al...', score: 19.801461834952015), context=None, document_offset=ExtractedAnswer.Span(start=125, end=160), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.48066219687461853, data=' Monday - Saturday 4:00 PM - 12:00 AM, Sunday - Closed', document=Document(id=829cb8c526265bc03477b109eb89acda01db27d62b51c8fa586ca3c63ec56afd, content: 'Zarpe, Bar, Cocktails, Alcohol, LASENORA@ZARPE.BAR, Monday - Saturday 4:00 PM - 12:00 AM, Sunday - C...', score: 16.35872539077387), context=None, document_offset=ExtractedAnswer.Span(start=51, end=105), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.3035110831260681, data=' Playa Penca is a small beach with white sand, turquoise sea and gentle waves, surrounded by mountains that decorate the landscape.\n\nThe beach can only be reached by car. When entering the territory, the guard may ask for your details. After entering, you need to drive a few kilometers, where you can park your car. Then you will have to walk along a steep path to the beach.\n\nA few kilometers before the beach, the dirt road is in very poor condition.', document=Document(id=6342201df19b911553662e9e481f0f9bf914e8ccfe1a9a939ea63639ab259042, content: 'Playa Penca, Beaches, no information available, no information available, Playa Penca, Playa Penca i...', score: 15.336497346728873), context=None, document_offset=ExtractedAnswer.Span(start=86, end=539), context_offset=None, meta={}),
#    ExtractedAnswer(query='When is open the restaurant Zi Lounge?', score=0.0877363670074346, data=None, document=None, context=None, document_offset=None, context_offset=None, meta={})]}}
